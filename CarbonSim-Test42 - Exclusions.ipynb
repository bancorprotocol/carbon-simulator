# %%
from carbon import CarbonSimulatorUI, P, __version__, __date__
print(f"Carbon v{__version__} ({__date__})")
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CarbonSimulatorUI))
# Out:
# Carbon v2.0-beta2 (8/Dec/2022)
# CarbonSimulatorUI v2.1+excl3 (8/Dec/2022)

# %% [markdown]
# # Carbon Simulation - Test 42 - Exclusions

# %%
Sim = CarbonSimulatorUI(pair="ETH/USDC", raiseonerror=True)
Sim
# Out:
# CarbonSimulatorUI(<0 orders, 0 trades>, pair='ETH/USDC', mm='exact', xf=True)

# %%
for i in range(3):
    Sim.add_strategy("ETH", 10+0.1*i, 2000+10*i, 3000, 1000+10*i, 1001-10*i, 750)
    Sim.add_strategy("ETH", 11+0.1*i, 2000+10*i, 3000, None, None, None)
    Sim.add_strategy("ETH", None, None, None, 1001+10*i, 1001-10*i, 750)

# %%
o = Sim.state()["orders"]
assert len(o) == 18
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 1    1  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1001.0   750.0
# 2    2  ETHUSDC   ETH    11.0    11.0    ETH     False  2000.0  3000.0
# 3    3  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 4    4  ETHUSDC   ETH     0.0     0.0    ETH      True    None    None
# 5    5  ETHUSDC  USDC  1001.0  1001.0   USDC     False  1001.0   750.0
# 6    6  ETHUSDC   ETH    10.1    10.1    ETH     False  2010.0  3000.0
# 7    7  ETHUSDC  USDC  1010.0  1010.0   USDC     False   991.0   750.0
# 8    8  ETHUSDC   ETH    11.1    11.1    ETH     False  2010.0  3000.0
# 9    9  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 10  10  ETHUSDC   ETH     0.0     0.0    ETH      True    None    None
# 11  11  ETHUSDC  USDC  1011.0  1011.0   USDC     False   991.0   750.0
# 12  12  ETHUSDC   ETH    10.2    10.2    ETH     False  2020.0  3000.0
# 13  13  ETHUSDC  USDC  1020.0  1020.0   USDC     False   981.0   750.0
# 14  14  ETHUSDC   ETH    11.2    11.2    ETH     False  2020.0  3000.0
# 15  15  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 16  16  ETHUSDC   ETH     0.0     0.0    ETH      True    None    None
# 17  17  ETHUSDC  USDC  1021.0  1021.0   USDC     False   981.0   750.0
#
#     p_marg        p_unit  lid
# 0   2000.0  USDC per ETH    1
# 1   1001.0  USDC per ETH    0
# 2   2000.0  USDC per ETH    3
# 3     None  USDC per ETH    2
# 4     None  USDC per ETH    5
# 5   1001.0  USDC per ETH    4
# 6   2010.0  USDC per ETH    7
# 7    991.0  USDC per ETH    6
# 8   2010.0  USDC per ETH    9
# 9     None  USDC per ETH    8
# 10    None  USDC per ETH   11
# 11   991.0  USDC per ETH   10
# 12  2020.0  USDC per ETH   13
# 13   981.0  USDC per ETH   12
# 14  2020.0  USDC per ETH   15
# 15    None  USDC per ETH   14
# 16    None  USDC per ETH   17
# 17   981.0  USDC per ETH   16

# %%
o = Sim.state()["orders"].query("disabled==False")
assert len(o) == 12
print(list(o.query("tkn=='ETH'")["id"]))
assert list(o.query("tkn=='ETH'")["id"]) == [0, 2, 6, 8, 12, 14]
print(list(o.query("tkn=='USDC'")["id"]))
assert list(o.query("tkn=='USDC'")["id"]) == [1, 5, 7, 11, 13, 17]
o
# Out:
# [0, 2, 6, 8, 12, 14]
# [1, 5, 7, 11, 13, 17]
#     id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 1    1  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1001.0   750.0
# 2    2  ETHUSDC   ETH    11.0    11.0    ETH     False  2000.0  3000.0
# 5    5  ETHUSDC  USDC  1001.0  1001.0   USDC     False  1001.0   750.0
# 6    6  ETHUSDC   ETH    10.1    10.1    ETH     False  2010.0  3000.0
# 7    7  ETHUSDC  USDC  1010.0  1010.0   USDC     False   991.0   750.0
# 8    8  ETHUSDC   ETH    11.1    11.1    ETH     False  2010.0  3000.0
# 11  11  ETHUSDC  USDC  1011.0  1011.0   USDC     False   991.0   750.0
# 12  12  ETHUSDC   ETH    10.2    10.2    ETH     False  2020.0  3000.0
# 13  13  ETHUSDC  USDC  1020.0  1020.0   USDC     False   981.0   750.0
# 14  14  ETHUSDC   ETH    11.2    11.2    ETH     False  2020.0  3000.0
# 17  17  ETHUSDC  USDC  1021.0  1021.0   USDC     False   981.0   750.0
#
#     p_marg        p_unit  lid
# 0   2000.0  USDC per ETH    1
# 1   1001.0  USDC per ETH    0
# 2   2000.0  USDC per ETH    3
# 5   1001.0  USDC per ETH    4
# 6   2010.0  USDC per ETH    7
# 7    991.0  USDC per ETH    6
# 8   2010.0  USDC per ETH    9
# 11   991.0  USDC per ETH   10
# 12  2020.0  USDC per ETH   13
# 13   981.0  USDC per ETH   12
# 14  2020.0  USDC per ETH   15
# 17   981.0  USDC per ETH   16

# %%
t = Sim.amm_sells("ETH", 10, execute=False)["trades"]
print(list(t.query("aggr==False")["routeix"]))
assert(list(t.query("aggr==False")["routeix"])==[0, 2, 6, 8, 12, 14])
t
# Out:
# [0, 2, 6, 8, 12, 14]
#    uid  id subid                            note   aggr   exec limitfail  \
# 0  0.0   0     0                        route #0  False  False      None
# 0  0.1   0     1                        route #2  False  False      None
# 0  0.2   0     2                        route #6  False  False      None
# 0  0.3   0     3                        route #8  False  False      None
# 0  0.4   0     4                       route #12  False  False      None
# 0  0.5   0     5                       route #14  False  False      None
# 0    0   0     A  AMM sells 10ETH buys 20689USDC   True  False      None
#
#         amt1 tkn1          amt2  tkn2     pair               routeix  nroutes  \
# 0   1.688189  ETH   3484.318505  USDC  ETHUSDC                     0        1
# 0   1.857008  ETH   3832.750356  USDC  ETHUSDC                     2        1
# 0   1.589560  ETH   3288.945962  USDC  ETHUSDC                     6        1
# 0   1.746942  ETH   3614.584176  USDC  ETHUSDC                     8        1
# 0   1.486293  ETH   3082.916437  USDC  ETHUSDC                    12        1
# 0   1.632008  ETH   3385.163146  USDC  ETHUSDC                    14        1
# 0  10.000000  ETH  20688.678581  USDC  ETHUSDC  [0, 2, 6, 8, 12, 14]        6
#
#          price        p_unit
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH
# 0  2068.867858  USDC per ETH

# %% [markdown]
# ## Whitelist (`use_positions`)

# %%
t = Sim.amm_sells("ETH", 10, use_positions=[0,2], execute=False)["trades"]
print(list(t.query("aggr==False")["routeix"]))
assert(list(t.query("aggr==False")["routeix"])==[0, 2])
t
# Out:
# [0, 2]
#    uid  id subid                            note   aggr   exec limitfail  \
# 0  1.0   1     0                        route #0  False  False      None
# 0  1.1   1     1                        route #2  False  False      None
# 0    1   1     A  AMM sells 10ETH buys 21915USDC   True  False      None
#
#         amt1 tkn1          amt2  tkn2     pair routeix  nroutes        price  \
# 0   4.761905  ETH  10435.708678  USDC  ETHUSDC       0        1  2191.498822
# 0   5.238095  ETH  11479.279545  USDC  ETHUSDC       2        1  2191.498822
# 0  10.000000  ETH  21914.988223  USDC  ETHUSDC  [0, 2]        2  2191.498822
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
t = Sim.amm_sells("ETH", 10, use_positions=[6,12], execute=False)["trades"]
print(list(t.query("aggr==False")["routeix"]))
assert(list(t.query("aggr==False")["routeix"])==[6,12])
t
# Out:
# [6, 12]
#    uid  id subid                            note   aggr   exec limitfail  \
# 0  2.0   2     0                        route #6  False  False      None
# 0  2.1   2     1                       route #12  False  False      None
# 0    2   2     A  AMM sells 10ETH buys 22116USDC   True  False      None
#
#         amt1 tkn1          amt2  tkn2     pair  routeix  nroutes        price  \
# 0   5.010777  ETH  11068.095875  USDC  ETHUSDC        6        1  2211.596325
# 0   4.989223  ETH  11047.867378  USDC  ETHUSDC       12        1  2211.596325
# 0  10.000000  ETH  22115.963254  USDC  ETHUSDC  [6, 12]        2  2211.596325
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %% [markdown]
# ## Blacklist (`exclude_positions`)

# %%
t = Sim.amm_sells("ETH", 10, excl_positions=[8,12,14], execute=False)["trades"]
print(list(t.query("aggr==False")["routeix"]))
assert(list(t.query("aggr==False")["routeix"])==[0, 2, 6])
t
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-45c1c7d1dff5> in <module>
# ----> 1 t = Sim.amm_sells("ETH", 10, excl_positions=[8,12,14], execute=False)["trades"]
#       2 print(list(t.query("aggr==False")["routeix"]))
#       3 #assert(list(t.query("aggr==False")["routeix"])==[0, 2, 6])
#       4 t
#
# ~/REPOES/Bancor/CarbonSimulator/carbon/simulators/carbon_simulator.py in amm_sells(self, tkn, amt, pair, execute, inpair, limit_price, threshold_orders, use_positions, excl_positions, use_positions_matchlevel)
#     798             self._assert_position_is_valid(tkn, carbon_pair)
#     799
# --> 800             return self._trade(
#     801                 tkn=tkn,
#     802                 amt=-Decimal(str(amt)),
#
# ~/REPOES/Bancor/CarbonSimulator/carbon/simulators/carbon_simulator.py in _trade(self, tkn, amt, carbon_pair, trade_action, trade_description, execute, limit_price, inpair, use_positions, excl_positions, threshold_orders, use_positions_matchlevel)
#     449             if not excl_positions is None:
#     450                 excl_positions = set(excl_positions)
# --> 451                 raise ValueError("Excluding positions not implemented yet", excl_positions)
#     452
#     453             if not inpair:
#
# ValueError: ('Excluding positions not implemented yet', {8, 12, 14})

# %%
t
