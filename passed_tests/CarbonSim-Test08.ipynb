# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.4 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 8
#
# USDCETH vs ETHUSDC and `state`

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", verbose=False)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.add_sgl_pos("ETH", 100, 2000, 2000)["orders"]
Sim.add_sgl_pos("ETH", 100, 2000, 2000)["orders"]
Sim.state(pair="ETHUSDC")["orders"]
# Out:
#    id     pair tkn_name       y_int           y y_unit      p_start  \
# 0   0  ETHUSDC      ETH  100.000000  100.000000    ETH  2000.000000
# 1   1  ETHUSDC      ETH  100.000000  100.000000    ETH  2000.000000
#
#          p_end        p_unit  linked_to_id
# 0  2000.000000  USDC per ETH             0
# 1  2000.000000  USDC per ETH             1

# %%
Sim.add_sgl_pos("ETH", 100, 1/2000, 1/2000, pair="USDCETH")["orders"]
Sim.add_sgl_pos("ETH", 100, 1/2000, 1/2000, pair="USDCETH")["orders"]
Sim.state(pair="USDCETH")["orders"]
# Out:
#    id     pair tkn_name       y_int           y y_unit   p_start     p_end  \
# 2   2  USDCETH      ETH  100.000000  100.000000    ETH  0.000500  0.000500
# 3   3  USDCETH      ETH  100.000000  100.000000    ETH  0.000500  0.000500
#
#          p_unit  linked_to_id
# 2  ETH per USDC             2
# 3  ETH per USDC             3

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name       y_int           y y_unit      p_start  \
# 0   0  ETHUSDC      ETH  100.000000  100.000000    ETH  2000.000000
# 1   1  ETHUSDC      ETH  100.000000  100.000000    ETH  2000.000000
# 2   2  USDCETH      ETH  100.000000  100.000000    ETH     0.000500
# 3   3  USDCETH      ETH  100.000000  100.000000    ETH     0.000500
#
#          p_end        p_unit  linked_to_id
# 0  2000.000000  USDC per ETH             0
# 1  2000.000000  USDC per ETH             1
# 2     0.000500  ETH per USDC             2
# 3     0.000500  ETH per USDC             3

# %%
Sim.amm_sells("ETH", 10, pair="ETHUSDC", execute=False)["trades"]
# Out:
#    uid  id sub_id                            note   aggr   exec  amt1 tkn1  \
# 0  0.0   0      0                        route #0  False  False   2.5  ETH
# 0  0.1   0      1                        route #1  False  False   2.5  ETH
# 0  0.2   0      2                        route #2  False  False   2.5  ETH
# 0  0.3   0      3                        route #3  False  False   2.5  ETH
# 0    0   0      A  AMM sells 10ETH buys 20000USDC   True  False  10.0  ETH
#
#       amt2  tkn2     pair route_indexes  num_trades price_avg        p_unit
# 0   5000.0  USDC  ETHUSDC             0           1    2000.0  USDC per ETH
# 0   5000.0  USDC  ETHUSDC             1           1    2000.0  USDC per ETH
# 0   5000.0  USDC  ETHUSDC             2           1    2000.0  USDC per ETH
# 0   5000.0  USDC  ETHUSDC             3           1    2000.0  USDC per ETH
# 0  20000.0  USDC  ETHUSDC  [0, 1, 2, 3]           4    2000.0  USDC per ETH

# %%
Sim.amm_sells("ETH", 10, pair="USDCETH", execute=False)["trades"]
# Out:
#    uid  id sub_id                            note   aggr   exec  amt1 tkn1  \
# 0  1.0   1      0                        route #0  False  False   2.5  ETH
# 0  1.1   1      1                        route #1  False  False   2.5  ETH
# 0  1.2   1      2                        route #2  False  False   2.5  ETH
# 0  1.3   1      3                        route #3  False  False   2.5  ETH
# 0    1   1      A  AMM sells 10ETH buys 20000USDC   True  False  10.0  ETH
#
#       amt2  tkn2     pair route_indexes  num_trades price_avg        p_unit
# 0   5000.0  USDC  USDCETH             0           1    0.0005  ETH per USDC
# 0   5000.0  USDC  USDCETH             1           1    0.0005  ETH per USDC
# 0   5000.0  USDC  USDCETH             2           1    0.0005  ETH per USDC
# 0   5000.0  USDC  USDCETH             3           1    0.0005  ETH per USDC
# 0  20000.0  USDC  USDCETH  [0, 1, 2, 3]           4    0.0005  ETH per USDC
