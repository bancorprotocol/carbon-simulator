# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *
import pandas as pd
import numpy as np

# %%
print("[carbon_simulator] version", uiversion, uidate)
jv()
# Out:
# [carbon_simulator] version 1.0 beta4 15/Nov/2022
# <div style='color:grey; font-size: 120%'><p><strong>This notebook is in the process of verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 34

# %%
Sim = CarbonSimulatorUI(verbose=False, raiseonerror=True)
Sim
# Out:
# CarbonSimulatorUI(<0 orders, 0 trades>, pair='None')

# %%
Sim.add_order("ETH", 10, 2000, 3000, "ETHUSDC")
Sim.add_order("ETH", 20, 2010, 3010, "ETHUSDC")
Sim.add_order("ETH", 30, 2020, 3020, "ETHUSDC")
Sim.add_order("ETH", 40, 2030, 2030, "ETHUSDC")
Sim.add_strategy("ETH", 10, 2000, 3000, 5000, 1000, 900, "ETHUSDC")
Sim.add_strategy("ETH", 20, 2010, 3010, 5100, 1010, 910, "ETHUSDC")
Sim.add_strategy("ETH", 30, 2020, 3020, 5200, 1020, 920, "ETHUSDC")
Sim.add_strategy("ETH", 40, 2030, 3030, 5300, 1030, 930, "ETHUSDC")
Sim.add_order("ETH", 10, 2000, 3000, "ETHDAI")
Sim.add_order("ETH", 20, 2010, 3010, "ETHDAI")
Sim.add_order("ETH", 30, 2020, 3020, "ETHDAI")
Sim.add_order("ETH", 40, 2030, 2030, "ETHDAI")
Sim.add_strategy("ETH", 10, 2000, 3000, 5000, 1000, 900, "ETHDAI")
Sim.add_strategy("ETH", 20, 2010, 3010, 5100, 1010, 910, "ETHDAI")
Sim.add_strategy("ETH", 30, 2020, 3020, 5200, 1020, 920, "ETHDAI")
Sim.add_strategy("ETH", 40, 2030, 3030, 5300, 1030, 930, "ETHDAI")
Sim
# Out:
# CarbonSimulatorUI(<24 orders, 0 trades>, pair='None')

# %%
Sim.state()["orders"]
# Out:
#     id     pair   tkn   y_int       y y_unit  p_start   p_end  p_marg  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  3000.0  2000.0
# 1    1  ETHUSDC   ETH    20.0    20.0    ETH   2010.0  3010.0  2010.0
# 2    2  ETHUSDC   ETH    30.0    30.0    ETH   2020.0  3020.0  2020.0
# 3    3  ETHUSDC   ETH    40.0    40.0    ETH   2030.0  2030.0  2030.0
# 4    4  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  3000.0  2000.0
# 5    5  ETHUSDC  USDC  5000.0  5000.0   USDC   1000.0   900.0  1000.0
# 6    6  ETHUSDC   ETH    20.0    20.0    ETH   2010.0  3010.0  2010.0
# 7    7  ETHUSDC  USDC  5100.0  5100.0   USDC   1010.0   910.0  1010.0
# 8    8  ETHUSDC   ETH    30.0    30.0    ETH   2020.0  3020.0  2020.0
# 9    9  ETHUSDC  USDC  5200.0  5200.0   USDC   1020.0   920.0  1020.0
# 10  10  ETHUSDC   ETH    40.0    40.0    ETH   2030.0  3030.0  2030.0
# 11  11  ETHUSDC  USDC  5300.0  5300.0   USDC   1030.0   930.0  1030.0
# 12  12   ETHDAI   ETH    10.0    10.0    ETH   2000.0  3000.0  2000.0
# 13  13   ETHDAI   ETH    20.0    20.0    ETH   2010.0  3010.0  2010.0
# 14  14   ETHDAI   ETH    30.0    30.0    ETH   2020.0  3020.0  2020.0
# 15  15   ETHDAI   ETH    40.0    40.0    ETH   2030.0  2030.0  2030.0
# 16  16   ETHDAI   ETH    10.0    10.0    ETH   2000.0  3000.0  2000.0
# 17  17   ETHDAI   DAI  5000.0  5000.0    DAI   1000.0   900.0  1000.0
# 18  18   ETHDAI   ETH    20.0    20.0    ETH   2010.0  3010.0  2010.0
# 19  19   ETHDAI   DAI  5100.0  5100.0    DAI   1010.0   910.0  1010.0
# 20  20   ETHDAI   ETH    30.0    30.0    ETH   2020.0  3020.0  2020.0
# 21  21   ETHDAI   DAI  5200.0  5200.0    DAI   1020.0   920.0  1020.0
# 22  22   ETHDAI   ETH    40.0    40.0    ETH   2030.0  3030.0  2030.0
# 23  23   ETHDAI   DAI  5300.0  5300.0    DAI   1030.0   930.0  1030.0
#
#           p_unit  lid
# 0   USDC per ETH    0
# 1   USDC per ETH    1
# 2   USDC per ETH    2
# 3   USDC per ETH    3
# 4   USDC per ETH    5
# 5   USDC per ETH    4
# 6   USDC per ETH    7
# 7   USDC per ETH    6
# 8   USDC per ETH    9
# 9   USDC per ETH    8
# 10  USDC per ETH   11
# 11  USDC per ETH   10
# 12   DAI per ETH   12
# 13   DAI per ETH   13
# 14   DAI per ETH   14
# 15   DAI per ETH   15
# 16   DAI per ETH   17
# 17   DAI per ETH   16
# 18   DAI per ETH   19
# 19   DAI per ETH   18
# 20   DAI per ETH   21
# 21   DAI per ETH   20
# 22   DAI per ETH   23
# 23   DAI per ETH   22

# %%
df = Sim.liquidity(Sim.ASDF)
df
# Out:
#                     y
# pair    tkn
# ETHDAI  DAI   20600.0
#         ETH     200.0
# ETHUSDC ETH     200.0
#         USDC  20600.0

# %%
dct = df.to_dict(orient='dict')["y"]
dct
# Out:
# {('ETHDAI', 'DAI'): 20600.0,
#  ('ETHDAI', 'ETH'): 200.0,
#  ('ETHUSDC', 'ETH'): 200.0,
#  ('ETHUSDC', 'USDC'): 20600.0}

# %%
pairs = set(k[0] for k in dct)
pairs
# Out:
# {'ETHDAI', 'ETHUSDC'}

# %%
{p:{k[1]:1 for k in dct if k[0]==p} for p in pairs}
# Out:
# {'ETHUSDC': {'ETH': 1, 'USDC': 1}, 'ETHDAI': {'DAI': 1, 'ETH': 1}}

# %%
Sim.liquidity(Sim.ASDICT)
# Out:
# {'ETHUSDC': {'ETH': 200.0, 'USDC': 20600.0},
#  'ETHDAI': {'DAI': 20600.0, 'ETH': 200.0}}

# %%
Sim.liquidity()
# Out:
# {'ETHUSDC': {'ETH': 200.0, 'USDC': 20600.0},
#  'ETHDAI': {'DAI': 20600.0, 'ETH': 200.0}}
