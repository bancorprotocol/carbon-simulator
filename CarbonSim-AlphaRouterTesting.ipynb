# %%
from test_positions import *
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
print("[carbon.ui] version", uiversion, uidate)
# Out:
# [carbon.ui] version 1.0 21/Nov/2022

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", verbose=False)
Sim2 = CarbonSimulatorUI(pair="ETHUSDC", verbose=False, matching_method='alpha')

# %%
input_dictionary = input_dictionary_5

# %%
input_dictionary
# Out:
# {0: {'token_1': 'eth',
#   'token_2': 'usdc',
#   'token_1_p_a': Decimal('0.0005000000000000'),
#   'token_1_p_b': Decimal('0.0004000000000000'),
#   'token_1_y_int': Decimal('10.00000000000000000'),
#   'token_2_p_a': Decimal('2800.000000000000000'),
#   'token_2_p_b': Decimal('2700.000000000000000'),
#   'token_2_y_int': Decimal('1.00000000000000')},
#  1: {'token_1': 'eth',
#   'token_2': 'usdc',
#   'token_1_p_a': Decimal('0.0005000000000000'),
#   'token_1_p_b': Decimal('0.0004000000000000'),
#   'token_1_y_int': Decimal('10.00000000000000000'),
#   'token_2_p_a': Decimal('2795.000000000000000'),
#   'token_2_p_b': Decimal('2705.000000000000000'),
#   'token_2_y_int': Decimal('1.00000000000000')},
#  2: {'token_1': 'eth',
#   'token_2': 'usdc',
#   'token_1_p_a': Decimal('0.0005000000000000'),
#   'token_1_p_b': Decimal('0.0004000000000000'),
#   'token_1_y_int': Decimal('10.00000000000000000'),
#   'token_2_p_a': Decimal('2790.000000000000000'),
# ...

# %%
_id = input_dictionary
for o in _id:
    i = _id[o]
    Sim.add_strategy(  i['token_1'].upper(),
                       i['token_1_y_int'],
                       1/i['token_1_p_a'],
                       1/i['token_1_p_b'],
                       i['token_2_y_int'],
                       i['token_2_p_a'],
                       i['token_2_p_b'],
                       pair=i['token_1'].upper()+i['token_2'].upper())
# #     Sim1.add_linked_pos("ETH",
# #                        i['token_1_y_int'],
# #                        i['token_1_p_a'],
# #                        i['token_1_p_b'],
# #                        i['token_2_y_int'],
# #                        i['token_2_p_a'],
# #                        i['token_2_p_b'],)
    Sim2.add_strategy( i['token_1'].upper(),
                       i['token_1_y_int'],
                       1/i['token_1_p_a'],
                       1/i['token_1_p_b'],
                       i['token_2_y_int'],
                       i['token_2_p_a'],
                       i['token_2_p_b'],
                       pair=i['token_1'].upper()+i['token_2'].upper())

# %%
Sim2.state()['orders']
# Out:
#     id     pair   tkn   y_int       y y_unit  p_start   p_end  p_marg  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 1    1  ETHUSDC  USDC     1.0     1.0   USDC   2800.0  2700.0  2800.0
# 2    2  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 3    3  ETHUSDC  USDC     1.0     1.0   USDC   2795.0  2705.0  2795.0
# 4    4  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 5    5  ETHUSDC  USDC     1.0     1.0   USDC   2790.0  2710.0  2790.0
# 6    6  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 7    7  ETHUSDC  USDC     1.0     1.0   USDC   2785.0  2715.0  2785.0
# 8    8  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 9    9  ETHUSDC  USDC     1.0     1.0   USDC   2780.0  2720.0  2780.0
# 10  10  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 11  11  ETHUSDC  USDC     1.0     1.0   USDC   2775.0  2725.0  2775.0
# ...

# %%
Sim.orders
# Out:
# {0: Order(B=0.02, S=0.0023606797749978967, y_int=Decimal('10.00000000000000000'), p_high=Decimal('0.0005'), p_low=Decimal('0.0004'), _y=Decimal('10.00000000000000000'), D=Decimal('10.00000000000000000'), _C=Decimal('10.00000000000000000'), pair=CarbonPair(tknb='ETH', tknq='USDC'), tkn='ETH', pair_name='ETHUSDC', adj_n_mode=False, auto_convert_variables=True, id=0, linked_to_id=1, _reverseq=False, verbose=False),
#  1: Order(B=51.96152422706632, S=0.9535019942254905, y_int=Decimal('1.00000000000000'), p_high=Decimal('2800.000000000000000'), p_low=Decimal('2700.000000000000000'), _y=Decimal('1.00000000000000'), D=Decimal('1.00000000000000'), _C=Decimal('1.00000000000000'), pair=CarbonPair(tknb='ETH', tknq='USDC'), tkn='USDC', pair_name='ETHUSDC', adj_n_mode=False, auto_convert_variables=True, id=1, linked_to_id=0, _reverseq=False, verbose=False),
# ...

# %%
trade_amount = 1000
Sim.amm_sells('USDC',trade_amount, execute=False)['trades']  # route_trade_by_target
# Sim.amm_sells('ETH', 1, execute=False)['trades']     # route_trade_by_target
# Sim.amm_buys('ETH', 1, execute=False)['trades']      # route_trade_by_source
# Sim.amm_buys('USDC', 1000, execute=False)['trades']  # route_trade_by_source
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  0.0   0     0                      route #1  False  False      None
# 0  0.1   0     1                      route #3  False  False      None
# 0  0.2   0     2                      route #5  False  False      None
# 0  0.3   0     3                      route #7  False  False      None
# 0  0.4   0     4                      route #9  False  False      None
# 0  0.5   0     5                     route #11  False  False      None
# 0  0.6   0     6                     route #13  False  False      None
# 0  0.7   0     7                     route #15  False  False      None
# 0  0.8   0     8                     route #17  False  False      None
# 0  0.9   0     9                     route #19  False  False      None
# 0    0   0     A  AMM sells 1000USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair  \
# 0     0.457723  USDC  0.000165  ETH  ETHUSDC
# ...

# %%
Sim2.state()['orders']
# Out:
#     id     pair   tkn   y_int       y y_unit  p_start   p_end  p_marg  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 1    1  ETHUSDC  USDC     1.0     1.0   USDC   2800.0  2700.0  2800.0
# 2    2  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 3    3  ETHUSDC  USDC     1.0     1.0   USDC   2795.0  2705.0  2795.0
# 4    4  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 5    5  ETHUSDC  USDC     1.0     1.0   USDC   2790.0  2710.0  2790.0
# 6    6  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 7    7  ETHUSDC  USDC     1.0     1.0   USDC   2785.0  2715.0  2785.0
# 8    8  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 9    9  ETHUSDC  USDC     1.0     1.0   USDC   2780.0  2720.0  2780.0
# 10  10  ETHUSDC   ETH    10.0    10.0    ETH   2000.0  2500.0  2000.0
# 11  11  ETHUSDC  USDC     1.0     1.0   USDC   2775.0  2725.0  2775.0
# ...

# %% [markdown]
# ### Currently only works for amm_sells (i.e. trade by target)

# %%
Sim2.amm_sells('USDC',trade_amount, execute=False, threshold_orders = 4)['trades']
# Out:
# [9, 8, 7, 6]
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  0.0   0     0                     route #13  False  False      None
# 0  0.1   0     1                     route #15  False  False      None
# 0  0.2   0     2                     route #17  False  False      None
# 0  0.3   0     3                     route #19  False  False      None
# 0    0   0     A  AMM sells 1000USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair           routeix  nroutes  \
# 0     0.399144  USDC  0.000145  ETH  ETHUSDC                13        1
# 0     0.366056  USDC  0.000133  ETH  ETHUSDC                15        1
# 0     0.299651  USDC  0.000109  ETH  ETHUSDC                17        1
# 0   998.935149  USDC  0.362656  ETH  ETHUSDC                19        1
# 0  1000.000000  USDC  0.363042  ETH  ETHUSDC  [13, 15, 17, 19]        4
#
#          price        p_unit  threshold_orders
# ...

# %%
Sim2.amm_sells('USDC',trade_amount, execute=False, threshold_orders = 3, use_positions=[15,19])['trades']
# Out:
# [1, 0]
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  1.0   1     0                     route #15  False  False      None
# 0  1.1   1     1                     route #19  False  False      None
# 0    1   1     A  AMM sells 1000USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair   routeix  nroutes        price  \
# 0     0.366079  USDC  0.000133  ETH  ETHUSDC        15        1  2754.501103
# 0   999.633921  USDC  0.362909  ETH  ETHUSDC        19        1  2754.501103
# 0  1000.000000  USDC  0.363042  ETH  ETHUSDC  [15, 19]        2  2754.501103
#
#          p_unit  threshold_orders
# 0  USDC per ETH                 3
# 0  USDC per ETH                 3
# 0  USDC per ETH                 3

# %%
Sim2.state()['trades']
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  0.0   0     0                     route #13  False  False      None
# 0  0.1   0     1                     route #15  False  False      None
# 0  0.2   0     2                     route #17  False  False      None
# 0  0.3   0     3                     route #19  False  False      None
# 0    0   0     A  AMM sells 1000USDC buys 0ETH   True  False      None
# 0  1.0   1     0                     route #15  False  False      None
# 0  1.1   1     1                     route #19  False  False      None
# 0    1   1     A  AMM sells 1000USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair           routeix  nroutes  \
# 0     0.399144  USDC  0.000145  ETH  ETHUSDC                13        1
# 0     0.366056  USDC  0.000133  ETH  ETHUSDC                15        1
# 0     0.299651  USDC  0.000109  ETH  ETHUSDC                17        1
# ...

# %%
Sim2.amm_sells('ETH',1, execute=False, threshold_orders = 4)['trades']
# Out:
# [0, 1, 2, 3]
#    uid  id subid                          note   aggr   exec limitfail  amt1  \
# 0  2.0   2     0                      route #0  False  False      None  0.25
# 0  2.1   2     1                      route #2  False  False      None  0.25
# 0  2.2   2     2                      route #4  False  False      None  0.25
# 0  2.3   2     3                      route #6  False  False      None  0.25
# 0    2   2     A  AMM sells 1ETH buys 2005USDC   True  False      None  1.00
#
#   tkn1         amt2  tkn2     pair       routeix  nroutes        price  \
# 0  ETH   501.323152  USDC  ETHUSDC             0        1  2005.292609
# 0  ETH   501.323152  USDC  ETHUSDC             2        1  2005.292609
# 0  ETH   501.323152  USDC  ETHUSDC             4        1  2005.292609
# 0  ETH   501.323152  USDC  ETHUSDC             6        1  2005.292609
# 0  ETH  2005.292609  USDC  ETHUSDC  [0, 2, 4, 6]        4  2005.292609
#
#          p_unit  threshold_orders
# ...

# %%
Sim.amm_sells('ETH',1, execute=False, threshold_orders = 4)['trades']
# Out:
#    uid  id subid                          note   aggr   exec limitfail  amt1  \
# 0  1.0   1     0                      route #0  False  False      None   0.1
# 0  1.1   1     1                      route #2  False  False      None   0.1
# 0  1.2   1     2                      route #4  False  False      None   0.1
# 0  1.3   1     3                      route #6  False  False      None   0.1
# 0  1.4   1     4                      route #8  False  False      None   0.1
# 0  1.5   1     5                     route #10  False  False      None   0.1
# 0  1.6   1     6                     route #12  False  False      None   0.1
# 0  1.7   1     7                     route #14  False  False      None   0.1
# 0  1.8   1     8                     route #16  False  False      None   0.1
# 0  1.9   1     9                     route #18  False  False      None   0.1
# 0    1   1     A  AMM sells 1ETH buys 2002USDC   True  False      None   1.0
#
# ...

# %%
Sim2.amm_buys('ETH', 0.5, execute=False, threshold_orders=4)['trades']      # route_trade_by_source
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  3.0   3     0                     route #13  False  False      None
# 0  3.1   3     1                     route #15  False  False      None
# 0  3.2   3     2                     route #17  False  False      None
# 0  3.3   3     3                     route #19  False  False      None
# 0    3   3     A  AMM sells 1377USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair           routeix  nroutes  \
# 0     0.408581  USDC  0.000148  ETH  ETHUSDC                13        1
# 0     0.378637  USDC  0.000137  ETH  ETHUSDC                15        1
# 0     0.318524  USDC  0.000116  ETH  ETHUSDC                17        1
# 0  1376.051704  USDC  0.499599  ETH  ETHUSDC                19        1
# 0  1377.157446  USDC  0.500000  ETH  ETHUSDC  [13, 15, 17, 19]        4
#
#          price        p_unit  threshold_orders
# 0  2754.314892  USDC per ETH                 4
# ...

# %%
Sim.amm_buys('ETH', 0.5, execute=False, threshold_orders=4)['trades']      # route_trade_by_source
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  2.0   2     0                      route #1  False  False      None
# 0  2.1   2     1                      route #3  False  False      None
# 0  2.2   2     2                      route #5  False  False      None
# 0  2.3   2     3                      route #7  False  False      None
# 0  2.4   2     4                      route #9  False  False      None
# 0  2.5   2     5                     route #11  False  False      None
# 0  2.6   2     6                     route #13  False  False      None
# 0  2.7   2     7                     route #15  False  False      None
# 0  2.8   2     8                     route #17  False  False      None
# 0  2.9   2     9                     route #19  False  False      None
# 0    2   2     A  AMM sells 1377USDC buys 0ETH   True  False      None
#
#           amt1  tkn1      amt2 tkn2     pair  \
# 0     0.461498  USDC  0.000166  ETH  ETHUSDC
# ...

# %%
Sim2.amm_buys('USDC', 1000, execute=False, threshold_orders=4)['trades']  # route_trade_by_source
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  4.0   4     0                      route #0  False  False      None
# 0  4.1   4     1                      route #2  False  False      None
# 0  4.2   4     2                      route #4  False  False      None
# 0  4.3   4     3                      route #6  False  False      None
# 0    4   4     A  AMM sells 0ETH buys 1000USDC   True  False      None
#
#        amt1 tkn1    amt2  tkn2     pair       routeix  nroutes       price  \
# 0  0.124835  ETH   250.0  USDC  ETHUSDC             0        1  2002.63932
# 0  0.124835  ETH   250.0  USDC  ETHUSDC             2        1  2002.63932
# 0  0.124835  ETH   250.0  USDC  ETHUSDC             4        1  2002.63932
# 0  0.124835  ETH   250.0  USDC  ETHUSDC             6        1  2002.63932
# 0  0.499341  ETH  1000.0  USDC  ETHUSDC  [0, 2, 4, 6]        4  2002.63932
#
#          p_unit  threshold_orders
# 0  USDC per ETH                 4
# ...

# %%
Sim.amm_buys('USDC', 1000, execute=False)['trades']      # route_trade_by_source
# Out:
#    uid  id subid                          note   aggr   exec limitfail  \
# 0  3.0   3     0                      route #0  False  False      None
# 0  3.1   3     1                      route #2  False  False      None
# 0  3.2   3     2                      route #4  False  False      None
# 0  3.3   3     3                      route #6  False  False      None
# 0  3.4   3     4                      route #8  False  False      None
# 0  3.5   3     5                     route #10  False  False      None
# 0  3.6   3     6                     route #12  False  False      None
# 0  3.7   3     7                     route #14  False  False      None
# 0  3.8   3     8                     route #16  False  False      None
# 0  3.9   3     9                     route #18  False  False      None
# 0    3   3     A  AMM sells 0ETH buys 1000USDC   True  False      None
#
#        amt1 tkn1    amt2  tkn2     pair                              routeix  \
# ...
