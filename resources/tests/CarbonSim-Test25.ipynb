# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.1 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 25

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", raiseonerror=True, verbose=False)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
help(Sim.add_linked_pos)
# Out:
# Help on method add_linked_pos in module carbon.simulators.carbon_simulator:
#
# add_linked_pos(tkn: str, amt: Any, psell1: Any, psell2: Any, amtr: Any, pbuy1: Any, pbuy2: Any, pair: str = None) -> Dict[str, Any] method of carbon.simulators.carbon_simulator.CarbonSimulatorUI instance
#     adds two linked position (one buy, one sell)
#
#     :tkn:       the token that is sold in the range psell1/2, eg "ETH"*
#     :amt:       the amount of `tkn` that is available for sale in range psell1/2
#     :psell1/2:  both ends of the sell `tkn` range**, quoted in the price convention of `pair`
#     :amtr:      the amount of the other token that is available for selling against tkn in range pbuy1/2
#     :pbuy1/2:   both ends of the buy `tkn` range**, quoted in the price convention of `pair`
#     :pair:      the token pair to which the position corresponds, eg "ETHUSD"*
#
#     *if the pair is not available in the simulator, or if `tkn` is not part of `pair`
#     an exception is thrown or an error record is returned
#     **p1, p2 are interchangeable, the code deals with sorting them to pmin, pmax

# %% [markdown]
# We assert that we can not add an unrelated position to this pair, either using an existing token like LINK, or a token like DNE (does not exist).

# %%
Sim.add_linked_pos("ETH", 10, 2000, 3000, 10000, 1000, 500)["orders"]
# Out:
#    id     pair tkn_name         y_int             y y_unit      p_start  \
# 0   0  ETHUSDC      ETH     10.000000     10.000000    ETH  2000.000000
# 1   1  ETHUSDC     USDC  10000.000000  10000.000000   USDC  1000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             1
# 1   500.000000  USDC per ETH             0

# %% [markdown]
# ## Sell ETH

# %%
Sim.amm_sells("ETH", 0.00001)["trades"]
# Out:
#    uid  id sub_id                       note   aggr     amt1 tkn1  amt2  tkn2  \
# 0  0.0   0      0                   route #0  False  0.00001  ETH  0.02  USDC
# 0    0   0   None  AMM sells 0ETH buys 0USDC   True  0.00001  ETH  0.02  USDC
#
#       pair route_indexes  num_trades    price_avg        p_unit
# 0  ETHUSDC             0           1  2000.000367  USDC per ETH
# 0  ETHUSDC           [0]           1  2000.000367  USDC per ETH

# %%
Sim.amm_sells("ETH", 1)["trades"]
# Out:
#    uid  id sub_id                          note   aggr  amt1 tkn1  \
# 0  1.0   1      0                      route #0  False   1.0  ETH
# 0    1   1   None  AMM sells 1ETH buys 2037USDC   True   1.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  2037.387498  USDC  ETHUSDC             0           1  2037.387498
# 0  2037.387498  USDC  ETHUSDC           [0]           1  2037.387498
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH

# %% [markdown]
# ## Buy ETH

# %%
Sim.amm_buys("ETH", 0.00001)["trades"]
# Out:
#    uid  id sub_id                       note   aggr  amt1  tkn1     amt2 tkn2  \
# 0  2.0   2      0                   route #1  False  0.01  USDC  0.00001  ETH
# 0    2   2   None  AMM sells 0USDC buys 0ETH   True  0.01  USDC  0.00001  ETH
#
#       pair route_indexes  num_trades   price_avg        p_unit
# 0  ETHUSDC             1           1  999.999757  USDC per ETH
# 0  ETHUSDC           [1]           1  999.999757  USDC per ETH

# %%
Sim.amm_buys("ETH", 1)["trades"]
# Out:
#    uid  id sub_id                         note   aggr        amt1  tkn1  amt2  \
# 0  3.0   3      0                     route #1  False  976.245591  USDC   1.0
# 0    3   3   None  AMM sells 976USDC buys 1ETH   True  976.245591  USDC   1.0
#
#   tkn2     pair route_indexes  num_trades   price_avg        p_unit
# 0  ETH  ETHUSDC             1           1  976.245591  USDC per ETH
# 0  ETH  ETHUSDC           [1]           1  976.245591  USDC per ETH

# %% [markdown]
# ## Trades

# %%
ji("Again, the initial trades are closer to the start-side of the range, and the ones after that move towards the end")
# Out:
# <div style='color:green; font-size: 150%'><p><strong>INFO</strong></p>
# <p>Again, the initial trades are closer to the start-side of the range, and the ones after that move towards the end</p></div>

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr        amt1  tkn1  \
# 0  0.0   0      0                      route #0  False    0.000010   ETH
# 0    0   0   None     AMM sells 0ETH buys 0USDC   True    0.000010   ETH
# 0  1.0   1      0                      route #0  False    1.000000   ETH
# 0    1   1   None  AMM sells 1ETH buys 2037USDC   True    1.000000   ETH
# 0  2.0   2      0                      route #1  False    0.010000  USDC
# 0    2   2   None     AMM sells 0USDC buys 0ETH   True    0.010000  USDC
# 0  3.0   3      0                      route #1  False  976.245591  USDC
# 0    3   3   None   AMM sells 976USDC buys 1ETH   True  976.245591  USDC
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0     0.020000  USDC  ETHUSDC             0           1  2000.000367
# 0     0.020000  USDC  ETHUSDC           [0]           1  2000.000367
# 0  2037.387498  USDC  ETHUSDC             0           1  2037.387498
# 0  2037.387498  USDC  ETHUSDC           [0]           1  2037.387498
# 0     0.000010   ETH  ETHUSDC             1           1   999.999757
# 0     0.000010   ETH  ETHUSDC           [1]           1   999.999757
# 0     1.000000   ETH  ETHUSDC             1           1   976.245591
# 0     1.000000   ETH  ETHUSDC           [1]           1   976.245591
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name         y_int             y y_unit      p_start  \
# 0   0  ETHUSDC      ETH     10.000000     10.000000    ETH  2000.000000
# 1   1  ETHUSDC     USDC  12037.407498  11061.151907   USDC  1000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             1
# 1   500.000000  USDC per ETH             0
