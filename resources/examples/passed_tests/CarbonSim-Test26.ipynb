# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.1 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 26

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", raiseonerror=True, verbose=True)
Sim
# Out:
# [__init__] pair=ETHUSDC, verbose=True, raiseonerror=True
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
#Sim.add_sgl_pos("LINK", 100, 2000, 2000)

# %%
Sim.add_sgl_pos("ETH", 10, 2000, 3000)
Sim.add_sgl_pos("ETH", 10, 2000, 2500)
Sim.add_sgl_pos("USDC", 10000, 1000, 500)
Sim.add_sgl_pos("USDC", 10000, 1000, 750)
Sim
# Out:
# [add_sgl_pos] added position: tkn=ETH, amt=10, p_lo=2000, p_hi=3000, pair=ETHUSDC
# [add_sgl_pos] added position: tkn=ETH, amt=10, p_lo=2000, p_hi=2500, pair=ETHUSDC
# [add_sgl_pos] added position: tkn=USDC, amt=10000, p_lo=1000, p_hi=500, pair=ETHUSDC
# [add_sgl_pos] added position: tkn=USDC, amt=10000, p_lo=1000, p_hi=750, pair=ETHUSDC
# CarbonSimulatorUI(<4 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name         y_int             y y_unit      p_start  \
# 0   0  ETHUSDC      ETH     10.000000     10.000000    ETH  2000.000000
# 1   1  ETHUSDC      ETH     10.000000     10.000000    ETH  2000.000000
# 2   2  ETHUSDC     USDC  10000.000000  10000.000000   USDC  1000.000000
# 3   3  ETHUSDC     USDC  10000.000000  10000.000000   USDC  1000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             0
# 1  2500.000000  USDC per ETH             1
# 2   500.000000  USDC per ETH             2
# 3   750.000000  USDC per ETH             3

# %%
Sim.amm_sells("ETH", 1)["trades"]
# Out:
# AMM sells 1ETH buys 2013USDC  (2 routes)
#    uid  id sub_id                          note   aggr      amt1 tkn1  \
# 0  0.0   0      0                      route #0  False  0.365208  ETH
# 0  0.1   0      1                      route #1  False  0.634792  ETH
# 0    0   0   None  AMM sells 1ETH buys 2013USDC   True  1.000000  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0   735.343053  USDC  ETHUSDC             0           1  2013.493796
# 0  1278.150744  USDC  ETHUSDC             1           1  2013.493796
# 0  2013.493796  USDC  ETHUSDC        [0, 1]           2  2013.493796
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.amm_buys("ETH", 1)["trades"]
# Out:
# AMM sells 991USDC buys 1ETH  (2 routes)
#    uid  id sub_id                         note   aggr        amt1  tkn1  \
# 0  1.0   1      0                     route #2  False  310.996133  USDC
# 0  1.1   1      1                     route #3  False  679.895002  USDC
# 0    1   1   None  AMM sells 991USDC buys 1ETH   True  990.891134  USDC
#
#        amt2 tkn2     pair route_indexes  num_trades   price_avg        p_unit
# 0  0.313855  ETH  ETHUSDC             2           1  990.891134  USDC per ETH
# 0  0.686145  ETH  ETHUSDC             3           1  990.891134  USDC per ETH
# 0  1.000000  ETH  ETHUSDC        [2, 3]           2  990.891134  USDC per ETH

# %%
Sim.amm_sells("USDC", 1)["trades"]
# Out:
# AMM sells 1USDC buys 0ETH  (2 routes)
#    uid  id sub_id                       note   aggr      amt1  tkn1      amt2  \
# 0  2.0   2      0                   route #2  False  0.313855  USDC  0.000320
# 0  2.1   2      1                   route #3  False  0.686145  USDC  0.000699
# 0    2   2   None  AMM sells 1USDC buys 0ETH   True  1.000000  USDC  0.001018
#
#   tkn2     pair route_indexes  num_trades   price_avg        p_unit
# 0  ETH  ETHUSDC             2           1  981.856131  USDC per ETH
# 0  ETH  ETHUSDC             3           1  981.856131  USDC per ETH
# 0  ETH  ETHUSDC        [2, 3]           2  981.856131  USDC per ETH

# %%
Sim.amm_buys("USDC", 1)["trades"]
# Out:
# AMM sells 0ETH buys 1USDC  (2 routes)
#    uid  id sub_id                       note   aggr      amt1 tkn1      amt2  \
# 0  3.0   3      0                   route #0  False  0.000180  ETH  0.364211
# 0  3.1   3      1                   route #1  False  0.000314  ETH  0.635789
# 0    3   3   None  AMM sells 0ETH buys 1USDC   True  0.000493  ETH  1.000000
#
#    tkn2     pair route_indexes  num_trades   price_avg        p_unit
# 0  USDC  ETHUSDC             0           1  2027.08538  USDC per ETH
# 0  USDC  ETHUSDC             1           1  2027.08538  USDC per ETH
# 0  USDC  ETHUSDC        [0, 1]           2  2027.08538  USDC per ETH

# %%
ji("we see a few things below (1) all trades are routed through two positions, (2) the marginal prices along the routes are the same (3) the tighter ranges get more volume (4) the earlier trades get a better price, and of course (5) buying ETH is arounf 1000, and selling around 2000 ")
# Out:
# <div style='color:green; font-size: 150%'><p><strong>INFO</strong></p>
# <p>we see a few things below (1) all trades are routed through two positions, (2) the marginal prices along the routes are the same (3) the tighter ranges get more volume (4) the earlier trades get a better price, and of course (5) buying ETH is arounf 1000, and selling around 2000 </p></div>

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr        amt1  tkn1  \
# 0  0.0   0      0                      route #0  False    0.365208   ETH
# 0  0.1   0      1                      route #1  False    0.634792   ETH
# 0    0   0   None  AMM sells 1ETH buys 2013USDC   True    1.000000   ETH
# 0  1.0   1      0                      route #2  False  310.996133  USDC
# 0  1.1   1      1                      route #3  False  679.895002  USDC
# 0    1   1   None   AMM sells 991USDC buys 1ETH   True  990.891134  USDC
# 0  2.0   2      0                      route #2  False    0.313855  USDC
# 0  2.1   2      1                      route #3  False    0.686145  USDC
# 0    2   2   None     AMM sells 1USDC buys 0ETH   True    1.000000  USDC
# 0  3.0   3      0                      route #0  False    0.000180   ETH
# 0  3.1   3      1                      route #1  False    0.000314   ETH
# 0    3   3   None     AMM sells 0ETH buys 1USDC   True    0.000493   ETH
#
# ...

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name         y_int            y y_unit      p_start  \
# 0   0  ETHUSDC      ETH     10.000000     9.634612    ETH  2000.000000
# 1   1  ETHUSDC      ETH     10.000000     9.364894    ETH  2000.000000
# 2   2  ETHUSDC     USDC  10000.000000  9688.690012   USDC  1000.000000
# 3   3  ETHUSDC     USDC  10000.000000  9319.418853   USDC  1000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             0
# 1  2500.000000  USDC per ETH             1
# 2   500.000000  USDC per ETH             2
# 3   750.000000  USDC per ETH             3
