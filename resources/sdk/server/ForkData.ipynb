# %%
import os
import json

# %% [markdown]
# # Fork Data

# %%
dir_path = '/Users/skl/Downloads'
fork_dirs = [d for d in os.listdir(dir_path) if os.path.isdir(os.path.join(dir_path, d)) and d.startswith('fork')]
newest_dir = max(fork_dirs, key=lambda d: os.path.getmtime(os.path.join(dir_path, d)))
fork = newest_dir[5:].split(" ")[0]
p = os.path.join(dir_path, newest_dir)
print(p)
# Out:
# /Users/skl/Downloads/fork-0e982c68-d3c1-4122-8879-fbae29595ce0 (2)

# %%
def rj(path, fn, field=None):
    
    ffn = os.path.join(path, fn)
    with open(ffn, 'r') as f:
        data = json.load(f)
    if field is None:
        return data
    return data.get(field)

# %%
cc = rj(p, "CarbonController.json", "address")
cc
# Out:
# '0x135E72f1b65227b1C8e59DC1217096A114086876'

# %%
v = rj(p, "Voucher.json", "address")
v
# Out:
# '0x7E9e1C552f9b6460f4c390F2E1a89B7524243700'

# %%
rpc = f"https://rpc.tenderly.co/fork/{fork}"
rpc
# Out:
# 'https://rpc.tenderly.co/fork/0e982c68-d3c1-4122-8879-fbae29595ce0'

# %%
print(f"""
const carbonControllerAddress="{cc}"
const voucherAddress="{v}"
const rpcUrl="{rpc}"


""")
# Out:
# const carbonControllerAddress="0x135E72f1b65227b1C8e59DC1217096A114086876"
# const voucherAddress="0x7E9e1C552f9b6460f4c390F2E1a89B7524243700"
# const rpcUrl="https://rpc.tenderly.co/fork/0e982c68-d3c1-4122-8879-fbae29595ce0"

# %%
print(f"""
////////////////////////////////
// auto-generated by ForkData.py
const sdkConfig = {{
    rpcUrl: "{rpc}",
    contractAddresses: {{
      carbonControllerAddress: "{cc}",
      voucherAddress: "{v}",
    }},
  }};
const sdk = new Sdk(sdkConfig);
// end auto-generated
////////////////////////////////
""")
# Out:
# ////////////////////////////////
# // auto-generated by ForkData.py
# const sdkConfig = {
#     rpcUrl: "https://rpc.tenderly.co/fork/0e982c68-d3c1-4122-8879-fbae29595ce0",
#     contractAddresses: {
#       carbonControllerAddress: "0x135E72f1b65227b1C8e59DC1217096A114086876",
#       voucherAddress: "0x7E9e1C552f9b6460f4c390F2E1a89B7524243700",
#     },
#   };
# const sdk = new Sdk(sdkConfig);
# // end auto-generated
# ////////////////////////////////
