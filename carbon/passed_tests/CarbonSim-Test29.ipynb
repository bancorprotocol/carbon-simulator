# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.5+2 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 29

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", verbose=False, raiseonerror=False)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.add_sgl_pos("ETH", 10, 2000, 3000)
Sim.add_sgl_pos("ETH", 20, 2000, 3000)
Sim.add_sgl_pos("ETH", 30, 2000, 3000)
Sim
# Out:
# CarbonSimulatorUI(<3 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.add_linked_pos("ETH", 10, 2000, 3000, 1000, 1000, 500)
Sim.add_linked_pos("ETH", 10, 2000, 3000, 1010, 1000, 500)
Sim.add_linked_pos("ETH", 10, 2000, 3000, 1010, 1000, 500)
Sim
# Out:
# CarbonSimulatorUI(<9 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name        y_int            y y_unit      p_start  \
# 0   0  ETHUSDC      ETH    10.000000    10.000000    ETH  2000.000000
# 1   1  ETHUSDC      ETH    20.000000    20.000000    ETH  2000.000000
# 2   2  ETHUSDC      ETH    30.000000    30.000000    ETH  2000.000000
# 3   3  ETHUSDC      ETH    10.000000    10.000000    ETH  2000.000000
# 4   4  ETHUSDC     USDC  1000.000000  1000.000000   USDC  1000.000000
# 5   5  ETHUSDC      ETH    10.000000    10.000000    ETH  2000.000000
# 6   6  ETHUSDC     USDC  1010.000000  1010.000000   USDC  1000.000000
# 7   7  ETHUSDC      ETH    10.000000    10.000000    ETH  2000.000000
# 8   8  ETHUSDC     USDC  1010.000000  1010.000000   USDC  1000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             0
# 1  3000.000000  USDC per ETH             1
# 2  3000.000000  USDC per ETH             2
# 3  3000.000000  USDC per ETH             4
# 4   500.000000  USDC per ETH             3
# ...

# %%
Sim.amm_sells("ETH", 1)
Sim.amm_buys("ETH", 1)
Sim.amm_sells("USDC", 1000)
Sim.amm_buys("USDC", 1000)
Sim
# Out:
# CarbonSimulatorUI(<9 positions, 4 trades>, pair='ETHUSDC')

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr  exec         amt1  \
# 0  0.0   0      0                      route #0  False  True     0.111111
# 0  0.1   0      1                      route #1  False  True     0.222222
# 0  0.2   0      2                      route #2  False  True     0.333333
# 0  0.3   0      3                      route #3  False  True     0.111111
# 0  0.4   0      4                      route #5  False  True     0.111111
# 0  0.5   0      5                      route #7  False  True     0.111111
# 0    0   0      A  AMM sells 1ETH buys 2004USDC   True  True     1.000000
# 0  1.0   1      0                      route #4  False  True   307.133940
# 0  1.1   1      1                      route #6  False  True   309.645921
# 0  1.2   1      2                      route #8  False  True   309.645921
# 0    1   1      A   AMM sells 926USDC buys 1ETH   True  True   926.425782
# 0  2.0   2      0                      route #4  False  True   331.525683
# ...

# %%
Sim.reset()
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.state()["orders"]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Sim.state()["trades"]
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
Sim.add_sgl_pos("ETH", 10, 2000, 3000)
Sim.amm_sells("ETH", 1)
Sim
# Out:
# CarbonSimulatorUI(<1 positions, 1 trades>, pair='ETHUSDC')

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int         y y_unit      p_start        p_end  \
# 0   0  ETHUSDC      ETH  10.000000  9.000000    ETH  2000.000000  3000.000000
#
#          p_unit  linked_to_id
# 0  USDC per ETH             0

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr  exec  amt1 tkn1  \
# 0  0.0   0      0                      route #0  False  True   1.0  ETH
# 0    0   0      A  AMM sells 1ETH buys 2037USDC   True  True   1.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_routes    price_avg  \
# 0  2037.386743  USDC  ETHUSDC             0           1  2037.386743
# 0  2037.386743  USDC  ETHUSDC           [0]           1  2037.386743
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
