# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.4 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test28

# %%
Sim = CarbonSimulatorUI(pair="ETHUSDC", verbose=False, raiseonerror=True)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='ETHUSDC')

# %%
Sim.add_sgl_pos("ETH", 10, 2000, 3000)
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int          y y_unit      p_start  \
# 0   0  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             0

# %%
Sim.amm_sells("ETH", 2, execute=False)["trades"]
# Out:
#    uid  id sub_id                          note   aggr   exec  amt1 tkn1  \
# 0  0.0   0      0                      route #0  False  False   2.0  ETH
# 0    0   0      A  AMM sells 2ETH buys 4152USDC   True  False   2.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  4152.395764  USDC  ETHUSDC             0           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr   exec  amt1 tkn1  \
# 0  0.0   0      0                      route #0  False  False   2.0  ETH
# 0    0   0      A  AMM sells 2ETH buys 4152USDC   True  False   2.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  4152.395764  USDC  ETHUSDC             0           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int          y y_unit      p_start  \
# 0   0  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#          p_end        p_unit  linked_to_id
# 0  3000.000000  USDC per ETH             0

# %%
Sim.amm_sells("ETH", 2, execute=True)["trades"]
# Out:
#    uid  id sub_id                          note   aggr  exec  amt1 tkn1  \
# 0  1.0   1      0                      route #0  False  True   2.0  ETH
# 0    1   1      A  AMM sells 2ETH buys 4152USDC   True  True   2.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  4152.395764  USDC  ETHUSDC             0           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr   exec  amt1 tkn1  \
# 0  0.0   0      0                      route #0  False  False   2.0  ETH
# 0    0   0      A  AMM sells 2ETH buys 4152USDC   True  False   2.0  ETH
# 0  1.0   1      0                      route #0  False   True   2.0  ETH
# 0    1   1      A  AMM sells 2ETH buys 4152USDC   True   True   2.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  4152.395764  USDC  ETHUSDC             0           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC             0           1  2076.197882
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["trades"].query("exec==False").query("aggr==True")
# Out:
#   uid  id sub_id                          note  aggr   exec  amt1 tkn1  \
# 0   0   0      A  AMM sells 2ETH buys 4152USDC  True  False   2.0  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades    price_avg  \
# 0  4152.395764  USDC  ETHUSDC           [0]           1  2076.197882
#
#          p_unit
# 0  USDC per ETH

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int         y y_unit      p_start        p_end  \
# 0   0  ETHUSDC      ETH  10.000000  8.000000    ETH  2000.000000  3000.000000
#
#          p_unit  linked_to_id
# 0  USDC per ETH             0
