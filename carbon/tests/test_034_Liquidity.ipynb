# %%
from carbon import CarbonSimulatorUI, P, __version__, __date__
print(f"Carbon v{__version__} ({__date__})")
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CarbonSimulatorUI))
# Out:
# Carbon v2.0-beta2 (8/Dec/2022)
# CarbonSimulatorUI v2.2 (8/Dec/2022)

# %% [markdown]
# # Carbon Simulation - Test 34 - Liquidity

# %%
Sim = CarbonSimulatorUI(verbose=False, raiseonerror=True)
Sim
# Out:
# CarbonSimulatorUI(<0 orders, 0 trades>, pair=None, mm='exact', xf=True)

# %%
Sim.add_order("ETH", 10, 2000, 3000, "ETH/USDC")
Sim.add_order("ETH", 20, 2010, 3010, "ETH/USDC")
Sim.add_order("ETH", 30, 2020, 3020, "ETH/USDC")
Sim.add_order("ETH", 40, 2030, 2030, "ETH/USDC")
Sim.add_strategy("ETH", 10, 2000, 3000, 5000, 1000, 900, "ETH/USDC")
Sim.add_strategy("ETH", 20, 2010, 3010, 5100, 1010, 910, "ETH/USDC")
Sim.add_strategy("ETH", 30, 2020, 3020, 5200, 1020, 920, "ETH/USDC")
Sim.add_strategy("ETH", 40, 2030, 3030, 5300, 1030, 930, "ETH/USDC")
Sim.add_order("ETH", 10, 2000, 3000, "ETH/DAI")
Sim.add_order("ETH", 20, 2010, 3010, "ETH/DAI")
Sim.add_order("ETH", 30, 2020, 3020, "ETH/DAI")
Sim.add_order("ETH", 40, 2030, 2030, "ETH/DAI")
Sim.add_strategy("ETH", 10, 2000, 3000, 5000, 1000, 900, "ETH/DAI")
Sim.add_strategy("ETH", 20, 2010, 3010, 5100, 1010, 910, "ETH/DAI")
Sim.add_strategy("ETH", 30, 2020, 3020, 5200, 1020, 920, "ETH/DAI")
Sim.add_strategy("ETH", 40, 2030, 3030, 5300, 1030, 930, "ETH/DAI")
Sim
# Out:
# CarbonSimulatorUI(<32 orders, 0 trades>, pair=None, mm='exact', xf=True)

# %%
r = Sim.state()["orders"]
assert len(r) == 32
assert sum(r.query("tkn == 'ETH'")["y"]) == 400
assert sum(r.query("tkn == 'USDC'")["y"]) == 20600
assert sum(r.query("tkn == 'DAI'")["y"]) == 20600
r
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  \
# 0    0  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 1    1  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 2    2  ETHUSDC   ETH    20.0    20.0    ETH     False  2010.0  3010.0
# 3    3  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 4    4  ETHUSDC   ETH    30.0    30.0    ETH     False  2020.0  3020.0
# 5    5  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 6    6  ETHUSDC   ETH    40.0    40.0    ETH     False  2030.0  2030.0
# 7    7  ETHUSDC  USDC     0.0     0.0   USDC      True    None    None
# 8    8  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 9    9  ETHUSDC  USDC  5000.0  5000.0   USDC     False  1000.0   900.0
# 10  10  ETHUSDC   ETH    20.0    20.0    ETH     False  2010.0  3010.0
# 11  11  ETHUSDC  USDC  5100.0  5100.0   USDC     False  1010.0   910.0
# 12  12  ETHUSDC   ETH    30.0    30.0    ETH     False  2020.0  3020.0
# 13  13  ETHUSDC  USDC  5200.0  5200.0   USDC     False  1020.0   920.0
# 14  14  ETHUSDC   ETH    40.0    40.0    ETH     False  2030.0  3030.0
# 15  15  ETHUSDC  USDC  5300.0  5300.0   USDC     False  1030.0   930.0
# 16  16   ETHDAI   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 17  17   ETHDAI   DAI     0.0     0.0    DAI      True    None    None
# 18  18   ETHDAI   ETH    20.0    20.0    ETH     False  2010.0  3010.0
# 19  19   ETHDAI   DAI     0.0     0.0    DAI      True    None    None
# 20  20   ETHDAI   ETH    30.0    30.0    ETH     False  2020.0  3020.0
# 21  21   ETHDAI   DAI     0.0     0.0    DAI      True    None    None
# 22  22   ETHDAI   ETH    40.0    40.0    ETH     False  2030.0  2030.0
# 23  23   ETHDAI   DAI     0.0     0.0    DAI      True    None    None
# 24  24   ETHDAI   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 25  25   ETHDAI   DAI  5000.0  5000.0    DAI     False  1000.0   900.0
# 26  26   ETHDAI   ETH    20.0    20.0    ETH     False  2010.0  3010.0
# 27  27   ETHDAI   DAI  5100.0  5100.0    DAI     False  1010.0   910.0
# 28  28   ETHDAI   ETH    30.0    30.0    ETH     False  2020.0  3020.0
# 29  29   ETHDAI   DAI  5200.0  5200.0    DAI     False  1020.0   920.0
# 30  30   ETHDAI   ETH    40.0    40.0    ETH     False  2030.0  3030.0
# 31  31   ETHDAI   DAI  5300.0  5300.0    DAI     False  1030.0   930.0
#
#     p_marg        p_unit  lid
# 0   2000.0  USDC per ETH    1
# 1     None  USDC per ETH    0
# 2   2010.0  USDC per ETH    3
# 3     None  USDC per ETH    2
# 4   2020.0  USDC per ETH    5
# 5     None  USDC per ETH    4
# 6   2030.0  USDC per ETH    7
# 7     None  USDC per ETH    6
# 8   2000.0  USDC per ETH    9
# 9   1000.0  USDC per ETH    8
# 10  2010.0  USDC per ETH   11
# 11  1010.0  USDC per ETH   10
# 12  2020.0  USDC per ETH   13
# 13  1020.0  USDC per ETH   12
# 14  2030.0  USDC per ETH   15
# 15  1030.0  USDC per ETH   14
# 16  2000.0   DAI per ETH   17
# 17    None   DAI per ETH   16
# 18  2010.0   DAI per ETH   19
# 19    None   DAI per ETH   18
# 20  2020.0   DAI per ETH   21
# 21    None   DAI per ETH   20
# 22  2030.0   DAI per ETH   23
# 23    None   DAI per ETH   22
# 24  2000.0   DAI per ETH   25
# 25  1000.0   DAI per ETH   24
# 26  2010.0   DAI per ETH   27
# 27  1010.0   DAI per ETH   26
# 28  2020.0   DAI per ETH   29
# 29  1020.0   DAI per ETH   28
# 30  2030.0   DAI per ETH   31
# 31  1030.0   DAI per ETH   30

# %%
df = Sim.liquidity(Sim.ASDF)
assert float(df.query("pair=='ETHDAI'").query("tkn=='DAI'")["y"]) == 20600
assert float(df.query("pair=='ETHUSDC'").query("tkn=='ETH'")["y"]) == 200
df
# Out:
#                     y
# pair    tkn
# ETHDAI  DAI   20600.0
#         ETH     200.0
# ETHUSDC ETH     200.0
#         USDC  20600.0

# %%
dct = df.to_dict(orient='dict')["y"]
assert dct[('ETHUSDC', 'USDC')] == 20600
dct
# Out:
# {('ETHDAI', 'DAI'): 20600.0,
#  ('ETHDAI', 'ETH'): 200.0,
#  ('ETHUSDC', 'ETH'): 200.0,
#  ('ETHUSDC', 'USDC'): 20600.0}

# %%
pairs = set(k[0] for k in dct)
assert pairs == {'ETHDAI', 'ETHUSDC'}
pairs
# Out:
# {'ETHDAI', 'ETHUSDC'}

# %%
{p:{k[1]:1 for k in dct if k[0]==p} for p in pairs}
# Out:
# {'ETHDAI': {'DAI': 1, 'ETH': 1}, 'ETHUSDC': {'ETH': 1, 'USDC': 1}}

# %%
Sim.liquidity(Sim.ASDICT)
# Out:
# {'ETHDAI': {'DAI': 20600.0, 'ETH': 200.0},
#  'ETHUSDC': {'ETH': 200.0, 'USDC': 20600.0}}

# %%
Sim.liquidity()
# Out:
# {'ETHDAI': {'DAI': 20600.0, 'ETH': 200.0},
#  'ETHUSDC': {'ETH': 200.0, 'USDC': 20600.0}}

# %%
assert Sim.liquidity(Sim.ASDICT) == Sim.liquidity()
