# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.1 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test 18

# %%
Sim = CarbonSimulatorUI(verbose=False, raiseonerror=False)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='None')

# %% [markdown]
# ## Single Positions

# %%
result = Sim.add_sgl_pos("ETH", 10, 2000, 3000, "ETHUSDC")
result = Sim.add_sgl_pos("ETH", 10, 2000, 3000, "ETHUSDC")
result = Sim.add_sgl_pos("ETH", 10, 2000, 3000, "ETHUSDC")
result = Sim.add_sgl_pos("ETH", 10, 2000, 2000, "ETHUSDC")

# %%
result
# Out:
# {'success': True,
#  'orders':    id     pair tkn_name      y_int          y y_unit      p_start  \
#  3   3  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#           p_end        p_unit  linked_to_id
#  3  2000.000000  USDC per ETH             3  }

# %%
result
# Out:
# {'success': True,
#  'orders':    id     pair tkn_name      y_int          y y_unit      p_start  \
#  3   3  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#           p_end        p_unit  linked_to_id
#  3  2000.000000  USDC per ETH             3  }

# %%
jw("I would like to see something like this here")
# Out:
# <div style='color:orange; font-size: 150%'><p><strong>WARNING</strong></p>
# <p>I would like to see something like this here</p></div>

# %%
result1 = {
    "success": True,
    "orders": result["orders"].iloc[[-1,]],
    "curves": "TODO -- PUT THE CURVE OBJECT(S) HERE AS LIST OF CURVES",
}
result1
# Out:
# {'success': True,
#  'orders':    id     pair tkn_name      y_int          y y_unit      p_start  \
#  3   3  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#           p_end        p_unit  linked_to_id
#  3  2000.000000  USDC per ETH             3  ,
#  'curves': 'TODO -- PUT THE CURVE OBJECT(S) HERE AS LIST OF CURVES'}

# %%
result1["orders"]
# Out:
#    id     pair tkn_name      y_int          y y_unit      p_start  \
# 3   3  ETHUSDC      ETH  10.000000  10.000000    ETH  2000.000000
#
#          p_end        p_unit  linked_to_id
# 3  2000.000000  USDC per ETH             3

# %% [markdown]
# ## Linked positions

# %%
Sim.add_linked_pos("USDC", 10, 2000, 3000, 1000, 500, 1000, "ETHUSDC")
Sim.add_linked_pos("USDC", 10, 2000, 3000, 1000, 500, 1000, "ETHUSDC")
Sim.add_linked_pos("USDC", 10, 2000, 3000, 1000, 500, 1000, "ETHUSDC")
result = Sim.add_linked_pos("USDC", 10, 2000, 2000, 1000, 1000, 1000, "ETHUSDC")
# Out:
# [_add_pos] swapped p_lo, p_hi
# [_add_pos] swapped p_lo, p_hi
# [_add_pos] swapped p_lo, p_hi

# %%
result
# Out:
# {'success': True,
#  'orders':     id     pair tkn_name        y_int            y y_unit      p_start  \
#  10  10  ETHUSDC     USDC    10.000000    10.000000   USDC  2000.000000
#  11  11  ETHUSDC      ETH  1000.000000  1000.000000    ETH  1000.000000
#
#            p_end        p_unit  linked_to_id
#  10  2000.000000  USDC per ETH            11
#  11  1000.000000  USDC per ETH            10  }

# %%
result["orders"]
# Out:
#     id     pair tkn_name        y_int            y y_unit      p_start  \
# 10  10  ETHUSDC     USDC    10.000000    10.000000   USDC  2000.000000
# 11  11  ETHUSDC      ETH  1000.000000  1000.000000    ETH  1000.000000
#
#           p_end        p_unit  linked_to_id
# 10  2000.000000  USDC per ETH            11
# 11  1000.000000  USDC per ETH            10

# %%
result1 = {
    "success": True,
    "orders": result["orders"].iloc[[-2,-1]],
    "curves": "TODO -- PUT THE CURVE OBJECT(S) HERE AS LIST OF CURVES",
}
result1
# Out:
# {'success': True,
#  'orders':     id     pair tkn_name        y_int            y y_unit      p_start  \
#  10  10  ETHUSDC     USDC    10.000000    10.000000   USDC  2000.000000
#  11  11  ETHUSDC      ETH  1000.000000  1000.000000    ETH  1000.000000
#
#            p_end        p_unit  linked_to_id
#  10  2000.000000  USDC per ETH            11
#  11  1000.000000  USDC per ETH            10  ,
#  'curves': 'TODO -- PUT THE CURVE OBJECT(S) HERE AS LIST OF CURVES'}

# %%
result1["orders"]
# Out:
#     id     pair tkn_name        y_int            y y_unit      p_start  \
# 10  10  ETHUSDC     USDC    10.000000    10.000000   USDC  2000.000000
# 11  11  ETHUSDC      ETH  1000.000000  1000.000000    ETH  1000.000000
#
#           p_end        p_unit  linked_to_id
# 10  2000.000000  USDC per ETH            11
# 11  1000.000000  USDC per ETH            10

# %% [markdown]
# ## Trading

# %%
result = Sim.amm_sells("ETH", 1, "ETHUSDC")
result = Sim.amm_sells("ETH", 1, "ETHUSDC")
result = Sim.amm_sells("ETH", 1, "ETHUSDC")
result = Sim.amm_sells("ETH", 1, "ETHUSDC")
result = Sim.amm_sells("ETH", 2, "ETHUSDC")

# %%
ji("This is fine already -- only shows the relevant trade data")
# Out:
# <div style='color:green; font-size: 150%'><p><strong>INFO</strong></p>
# <p>This is fine already -- only shows the relevant trade data</p></div>

# %%
result["trades"]
# Out:
#    uid  id sub_id                          note   aggr      amt1 tkn1  \
# 0  4.0   4      0                      route #5  False  0.666667  ETH
# 0  4.1   4      1                      route #7  False  0.666667  ETH
# 0  4.2   4      2                      route #9  False  0.666667  ETH
# 0    4   4   None  AMM sells 2ETH buys 1001USDC   True  2.000000  ETH
#
#           amt2  tkn2     pair route_indexes  num_trades   price_avg  \
# 0   333.659012  USDC  ETHUSDC             5           1  500.488517
# 0   333.659012  USDC  ETHUSDC             7           1  500.488517
# 0   333.659012  USDC  ETHUSDC             9           1  500.488517
# 0  1000.977035  USDC  ETHUSDC     [5, 7, 9]           3  500.488517
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                          note   aggr      amt1 tkn1  \
# 0  0.0   0      0                      route #5  False  0.333333  ETH
# 0  0.1   0      1                      route #7  False  0.333333  ETH
# 0  0.2   0      2                      route #9  False  0.333333  ETH
# 0    0   0   None   AMM sells 1ETH buys 500USDC   True  1.000000  ETH
# 0  1.0   1      0                      route #5  False  0.333333  ETH
# 0  1.1   1      1                      route #7  False  0.333333  ETH
# 0  1.2   1      2                      route #9  False  0.333333  ETH
# 0    1   1   None   AMM sells 1ETH buys 500USDC   True  1.000000  ETH
# 0  2.0   2      0                      route #5  False  0.333333  ETH
# 0  2.1   2      1                      route #7  False  0.333333  ETH
# 0  2.2   2      2                      route #9  False  0.333333  ETH
# 0    2   2   None   AMM sells 1ETH buys 500USDC   True  1.000000  ETH
# ...
