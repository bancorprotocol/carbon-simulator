# %%
from carbon import CarbonSimulatorUI
from carbon.simulators.carbon_simulator import (
    __version__ as uiversion,
    __date__ as uidate,
)
from jupyformat import *

# %%
print("[carbon_simulator] version", uiversion, uidate)
jp()
# Out:
# [carbon_simulator] version 0.9.10.1 12/Nov/2022
# <div style='color:green; font-size: 120%'><p><strong>This notebook passed verification.</strong></p></div>

# %% [markdown]
# # Carbon Simulation - Test19
#
# In this comprehensive test we test **multi-curve unidirectional liquidity with a zero width range**

# %%
Sim = CarbonSimulatorUI(pair="USDCETH", verbose=False)
Sim
# Out:
# CarbonSimulatorUI(<0 positions, 0 trades>, pair='USDCETH')

# %%
Sim.add_sgl_pos("ETH", 10, 1/2000, 1/2000)
Sim.add_sgl_pos("ETH", 10, 1/2010, 1/2010)
Sim.add_sgl_pos("ETH", 10, 1/2020, 1/2020)
Sim.add_sgl_pos("ETH", 10, 1/2030, 1/2030)
Sim.add_sgl_pos("ETH", 10, 1/2040, 1/2040)
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int          y y_unit   p_start     p_end  \
# 0   0  USDCETH      ETH  10.000000  10.000000    ETH  0.000500  0.000500
# 1   1  USDCETH      ETH  10.000000  10.000000    ETH  0.000498  0.000498
# 2   2  USDCETH      ETH  10.000000  10.000000    ETH  0.000495  0.000495
# 3   3  USDCETH      ETH  10.000000  10.000000    ETH  0.000493  0.000493
# 4   4  USDCETH      ETH  10.000000  10.000000    ETH  0.000490  0.000490
#
#          p_unit  linked_to_id
# 0  ETH per USDC             0
# 1  ETH per USDC             1
# 2  ETH per USDC             2
# 3  ETH per USDC             3
# 4  ETH per USDC             4

# %% [markdown]
# However, the AMM can sell 10 ETH, at a price of 2000.

# %%
Sim.amm_sells("ETH", 10)
Sim.amm_sells("ETH", 10)
Sim.amm_sells("ETH", 10)
Sim.amm_sells("ETH", 10)
Sim.amm_sells("ETH", 10)
Sim
# Out:
# CarbonSimulatorUI(<5 positions, 5 trades>, pair='USDCETH')

# %%
Sim.state()["trades"]
# Out:
#    uid  id sub_id                            note   aggr  amt1 tkn1     amt2  \
# 0  0.0   0      0                        route #0  False  10.0  ETH  20000.0
# 0    0   0   None  AMM sells 10ETH buys 20000USDC   True  10.0  ETH  20000.0
# 0  1.0   1      0                        route #1  False  10.0  ETH  20100.0
# 0    1   1   None  AMM sells 10ETH buys 20100USDC   True  10.0  ETH  20100.0
# 0  2.0   2      0                        route #2  False  10.0  ETH  20200.0
# 0    2   2   None  AMM sells 10ETH buys 20200USDC   True  10.0  ETH  20200.0
# 0  3.0   3      0                        route #3  False  10.0  ETH  20300.0
# 0    3   3   None  AMM sells 10ETH buys 20300USDC   True  10.0  ETH  20300.0
# 0  4.0   4      0                        route #4  False  10.0  ETH  20400.0
# 0    4   4   None  AMM sells 10ETH buys 20400USDC   True  10.0  ETH  20400.0
#
#    tkn2     pair route_indexes  num_trades price_avg        p_unit
# ...

# %%
Sim.state()["orders"]
# Out:
#    id     pair tkn_name      y_int         y y_unit   p_start     p_end  \
# 0   0  USDCETH      ETH  10.000000  0.000000    ETH  0.000500  0.000500
# 1   1  USDCETH      ETH  10.000000  0.000000    ETH  0.000498  0.000498
# 2   2  USDCETH      ETH  10.000000  0.000000    ETH  0.000495  0.000495
# 3   3  USDCETH      ETH  10.000000  0.000000    ETH  0.000493  0.000493
# 4   4  USDCETH      ETH  10.000000  0.000000    ETH  0.000490  0.000490
#
#          p_unit  linked_to_id
# 0  ETH per USDC             0
# 1  ETH per USDC             1
# 2  ETH per USDC             2
# 3  ETH per USDC             3
# 4  ETH per USDC             4

# %%
Sim.amm_sells("ETH", 10)
# Out:
# {'success': False,
#  'error': 'token ETH has no non-empty liquidity positions',
#  'exception': ValueError('token ETH has no non-empty liquidity positions')}
