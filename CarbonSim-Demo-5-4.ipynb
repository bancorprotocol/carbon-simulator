# %%
import pandas as pd
from decimal import Decimal
import math
from carbon import CarbonSimulatorUI, __version__, __date__
print(f"Carbon Version v{__version__} ({__date__})", )
# Out:
# Carbon Version v2.0-beta3 (12/Dec/2022)

# %% [markdown]
# # Carbon Simulation - Demo 5-4
#
# In this demo we investigate the **Fast Router performance** against test orders

# %% [markdown]
# Initialize a fast simulator

# %%
Sim = CarbonSimulatorUI(pair="USDC/ETH", verbose=False, matching_method='exact', raiseonerror=True)
FastSim = CarbonSimulatorUI(pair="USDC/ETH", verbose=False, matching_method='fast', raiseonerror=True)

# %% [markdown]
# Here we restrain the orders to just the top ones such that we can test the exact algo alongside

# %%
test_orders = pd.read_csv('256 orders with curr rate alternating.csv', dtype=float)
test_orders.rename(columns={'lowest-rate':'lowest_rate', 'highest-rate':'highest_rate', 'current-rate':'current_rate'}, inplace=True)
# test_orders['one_on_lowest_rate'] = 1/test_orders.lowest_rate
# test_orders['one_on_highest_rate'] = 1/test_orders.highest_rate
# test_orders['one_on_current_rate'] = 1/test_orders.current_rate
test_orders['y_int'] = [test_orders.liquidity[i] * (math.sqrt(test_orders.highest_rate[i]) - math.sqrt(test_orders.lowest_rate[i])) / (math.sqrt(test_orders.current_rate[i]) - math.sqrt(test_orders.lowest_rate[i])) for i in test_orders.index]
test_orders['fix_trade'] = test_orders.y_int - test_orders.liquidity
test_orders['y_int_minus_fixtrade'] = test_orders.y_int - test_orders.fix_trade
test_orders
# Out:
#         id    liquidity  lowest_rate  highest_rate  current_rate  \
# 0      0.0  254814732.0       1255.0        2255.0        1256.0
# 1      1.0  253827078.0       1254.0        2254.0        2254.0
# 2      2.0  252839424.0       1253.0        2253.0        1753.0
# 3      3.0  251851770.0       1252.0        2252.0        1253.0
# 4      4.0    6913578.0       1004.0        2004.0        1504.0
# ..     ...          ...          ...           ...           ...
# 251  251.0  250864116.0       1251.0        2251.0        2251.0
# 252  252.0    5925924.0       1003.0        2003.0        1004.0
# 253  253.0    4938270.0       1002.0        2002.0        2002.0
# 254  254.0    3950616.0       1001.0        2001.0        1501.0
# 255  255.0    2962962.0       1000.0        2000.0        1001.0
#
#             y_int     fix_trade  y_int_minus_fixtrade
# 0    2.177916e+11  2.175368e+11           254814732.0
# 1    2.538271e+08  0.000000e+00           253827078.0
# 2    4.715233e+08  2.186838e+08           252839424.0
# 3    2.151938e+11  2.149420e+11           251851770.0
# 4    1.274477e+07  5.831196e+06             6913578.0
# ..            ...           ...                   ...
# 251  2.508641e+08  0.000000e+00           250864116.0
# 252  4.912572e+09  4.906646e+09             5925924.0
# 253  4.938270e+06  0.000000e+00             4938270.0
# 254  7.281537e+06  3.330921e+06             3950616.0
# 255  2.455212e+09  2.452249e+09             2962962.0
#
# [256 rows x 8 columns]

# %%
test_orders['y_int'][0]
# Out:
# 217791634844.78958

# %%
test_orders['fix_trade'][0]
# Out:
# 217536820112.78958

# %% [markdown]
# To translate this order input (effectively p_a and p_b) into a meaningful order in the simulator we need to transform them
# The primary reason for this is that the current_rate (akin to p_marg) starts at the highest_rate (that has been denoted p_a) but the simulator takes the p_marg as being the p_start value in this pair

# %%
for i in test_orders.index:
    FastSim.add_strategy('ETH', Decimal(test_orders.y_int[i]), Decimal(test_orders.highest_rate[i]), Decimal(test_orders.lowest_rate[i]),  None, None, None)
    if test_orders.fix_trade[i] > 0:
        # print(i, i*2)
        # Sim.amm_sells('ETH', amt=test_orders.fix_trade[i], execute=True, use_positions=[i*2])['trades']
        FastSim.amm_sells('ETH', amt=test_orders.fix_trade[i], execute=True, use_positions=[i*2], use_positions_matchlevel=[i*2])['trades']
# FastSim.state()['orders'].query('tkn=="ETH"')

# %%
254559917268
# Out:
# 254559917268

# %%
trade_result = FastSim.state()['trades']
trade_result
# Out:
#       uid   id subid                                          note   aggr  \
# 0     0.0    0     0                                      route #0  False
# 0       0    0     A  AMM sells 217536820113ETH buys 129260158USDC   True
# 0     1.0    1     0                                      route #4  False
# 0       1    1     A        AMM sells 218683846ETH buys 110039USDC   True
# 0     2.0    2     0                                      route #6  False
# ..    ...  ...   ...                                           ...    ...
# 0     170  170     A      AMM sells 4906646218ETH buys 3460010USDC   True
# 0   171.0  171     0                                    route #508  False
# 0     171  171     A            AMM sells 3330921ETH buys 1922USDC   True
# 0   172.0  172     0                                    route #510  False
# 0     172  172     A      AMM sells 2452248625ETH buys 1733135USDC   True
#
#     exec limitfail          amt1 tkn1          amt2  tkn2     pair routeix  \
# 0   True      None  2.175368e+11  ETH  1.292602e+08  USDC  USDCETH       0
# 0   True      None  2.175368e+11  ETH  1.292602e+08  USDC  USDCETH     [0]
# 0   True      None  2.186838e+08  ETH  1.100386e+05  USDC  USDCETH       4
# 0   True      None  2.186838e+08  ETH  1.100386e+05  USDC  USDCETH     [4]
# 0   True      None  2.149420e+11  ETH  1.279562e+08  USDC  USDCETH       6
# ..   ...       ...           ...  ...           ...   ...      ...     ...
# 0   True      None  4.906646e+09  ETH  3.460010e+06  USDC  USDCETH   [504]
# 0   True      None  3.330921e+06  ETH  1.921987e+03  USDC  USDCETH     508
# 0   True      None  3.330921e+06  ETH  1.921987e+03  USDC  USDCETH   [508]
# 0   True      None  2.452249e+09  ETH  1.733135e+06  USDC  USDCETH     510
# 0   True      None  2.452249e+09  ETH  1.733135e+06  USDC  USDCETH   [510]
#
#     nroutes        price        p_unit
# 0         1  1683.501684  ETH per USDC
# 0         1  1683.501684  ETH per USDC
# 0         1  1988.071571  ETH per USDC
# 0         1  1988.071571  ETH per USDC
# 0         1  1680.672269  ETH per USDC
# ..      ...          ...           ...
# 0         1  1418.439716  ETH per USDC
# 0         1  1733.102253  ETH per USDC
# 0         1  1733.102253  ETH per USDC
# 0         1  1414.427157  ETH per USDC
# 0         1  1414.427157  ETH per USDC
#
# [346 rows x 16 columns]

# %%
trade_result['amt1'].values[0]
# Out:
# 217536820112.78958

# %% [markdown]
# We can see that when we input the order with flipped rates we get p_marg == p_start.
#
# Unfortunately this means that the pricing is flipped relative to the order input

# %%
eth_orders = FastSim.state()['orders'].query('tkn=="ETH"')
eth_orders
# Out:
#       id     pair  tkn         y_int            y y_unit  disabled p_start  \
# 0      0  USDCETH  ETH  2.177916e+11  254814732.0    ETH     False  2255.0
# 2      2  USDCETH  ETH  2.538271e+08  253827078.0    ETH     False  2254.0
# 4      4  USDCETH  ETH  4.715233e+08  252839424.0    ETH     False  2253.0
# 6      6  USDCETH  ETH  2.151938e+11  251851770.0    ETH     False  2252.0
# 8      8  USDCETH  ETH  1.274477e+07    6913578.0    ETH     False  2004.0
# ..   ...      ...  ...           ...          ...    ...       ...     ...
# 502  502  USDCETH  ETH  2.508641e+08  250864116.0    ETH     False  2251.0
# 504  504  USDCETH  ETH  4.912572e+09    5925924.0    ETH     False  2003.0
# 506  506  USDCETH  ETH  4.938270e+06    4938270.0    ETH     False  2002.0
# 508  508  USDCETH  ETH  7.281537e+06    3950616.0    ETH     False  2001.0
# 510  510  USDCETH  ETH  2.455212e+09    2962962.0    ETH     False  2000.0
#
#       p_end  p_marg        p_unit  lid
# 0    1255.0  1256.0  ETH per USDC    1
# 2    1254.0  2254.0  ETH per USDC    3
# 4    1253.0  1753.0  ETH per USDC    5
# 6    1252.0  1253.0  ETH per USDC    7
# 8    1004.0  1504.0  ETH per USDC    9
# ..      ...     ...           ...  ...
# 502  1251.0  2251.0  ETH per USDC  503
# 504  1003.0  1004.0  ETH per USDC  505
# 506  1002.0  2002.0  ETH per USDC  507
# 508  1001.0  1501.0  ETH per USDC  509
# 510  1000.0  1001.0  ETH per USDC  511
#
# [256 rows x 12 columns]

# %% [markdown]
# ## Route by Source

# %% [markdown]
# #### AMM buys USDC

# %% [markdown]
# We can then do a similar thing for the fast router

# %%
FastSim.amm_buys('USDC',10000000, execute=False)['trades']  # route_trade_by_source
# Out:
#         uid   id subid                                        note   aggr  \
# 0     173.0  173     0                                    route #2  False
# 0     173.1  173     1                                  route #502  False
# 0     173.2  173     2                                  route #496  False
# 0     173.3  173     3                                   route #20  False
# 0     173.4  173     4                                  route #484  False
# ..      ...  ...   ...                                         ...    ...
# 0   173.100  173   100                                   route #22  False
# 0   173.101  173   101                                  route #392  False
# 0   173.102  173   102                                   route #16  False
# 0   173.103  173   103                                  route #386  False
# 0       173  173     A  AMM sells 15482180833ETH buys 10000000USDC   True
#
#      exec limitfail          amt1 tkn1          amt2  tkn2     pair  \
# 0   False      None  2.538271e+08  ETH  1.509775e+05  USDC  USDCETH
# 0   False      None  2.508641e+08  ETH  1.494934e+05  USDC  USDCETH
# 0   False      None  2.479012e+08  ETH  1.480039e+05  USDC  USDCETH
# 0   False      None  2.449382e+08  ETH  1.465088e+05  USDC  USDCETH
# 0   False      None  2.419752e+08  ETH  1.450081e+05  USDC  USDCETH
# ..    ...       ...           ...  ...           ...   ...      ...
# 0   False      None  1.382716e+07  ETH  9.697309e+03  USDC  USDCETH
# 0   False      None  1.965431e+08  ETH  1.380001e+05  USDC  USDCETH
# 0   False      None  1.086419e+07  ETH  7.636342e+03  USDC  USDCETH
# 0   False      None  3.667345e+06  ETH  2.172790e+03  USDC  USDCETH
# 0   False      None  1.548218e+10  ETH  1.000000e+07  USDC  USDCETH
#
#                                               routeix  nroutes        price  \
# 0                                                   2        1  1548.218083
# 0                                                 502        1  1548.218083
# 0                                                 496        1  1548.218083
# 0                                                  20        1  1548.218083
# 0                                                 484        1  1548.218083
# ..                                                ...      ...          ...
# 0                                                  22        1  1548.218083
# 0                                                 392        1  1548.218083
# 0                                                  16        1  1548.218083
# 0                                                 386        1  1548.218083
# 0   [2, 502, 496, 20, 484, 478, 472, 466, 460, 56,...      104  1548.218083
#
#           p_unit
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# ..           ...
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
#
# [105 rows x 16 columns]

# %% [markdown]
# ## Route by Target

# %% [markdown]
# #### AMM sells ETH

# %%
FastSim.amm_sells('ETH',15482095361, execute=False)['trades']  # route_trade_by_target
# Out:
#         uid   id subid                                       note   aggr  \
# 0     174.0  174     0                                   route #2  False
# 0     174.1  174     1                                 route #502  False
# 0     174.2  174     2                                 route #496  False
# 0     174.3  174     3                                  route #20  False
# 0     174.4  174     4                                 route #484  False
# ..      ...  ...   ...                                        ...    ...
# 0   174.100  174   100                                  route #22  False
# 0   174.101  174   101                                 route #392  False
# 0   174.102  174   102                                  route #16  False
# 0   174.103  174   103                                 route #386  False
# 0       174  174     A  AMM sells 15482095361ETH buys 9999949USDC   True
#
#      exec limitfail          amt1 tkn1          amt2  tkn2     pair  \
# 0   False      None  2.538271e+08  ETH  1.509775e+05  USDC  USDCETH
# 0   False      None  2.508641e+08  ETH  1.494934e+05  USDC  USDCETH
# 0   False      None  2.479012e+08  ETH  1.480039e+05  USDC  USDCETH
# 0   False      None  2.449382e+08  ETH  1.465088e+05  USDC  USDCETH
# 0   False      None  2.419752e+08  ETH  1.450081e+05  USDC  USDCETH
# ..    ...       ...           ...  ...           ...   ...      ...
# 0   False      None  1.382716e+07  ETH  9.697309e+03  USDC  USDCETH
# 0   False      None  1.965431e+08  ETH  1.380001e+05  USDC  USDCETH
# 0   False      None  1.086419e+07  ETH  7.636342e+03  USDC  USDCETH
# 0   False      None  3.581873e+06  ETH  2.122000e+03  USDC  USDCETH
# 0   False      None  1.548210e+10  ETH  9.999949e+06  USDC  USDCETH
#
#                                               routeix  nroutes        price  \
# 0                                                   2        1  1547.987616
# 0                                                 502        1  1547.987616
# 0                                                 496        1  1547.987616
# 0                                                  20        1  1547.987616
# 0                                                 484        1  1547.987616
# ..                                                ...      ...          ...
# 0                                                  22        1  1547.987616
# 0                                                 392        1  1547.987616
# 0                                                  16        1  1547.987616
# 0                                                 386        1  1547.987616
# 0   [2, 502, 496, 20, 484, 478, 472, 466, 460, 56,...      104  1547.987616
#
#           p_unit
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# ..           ...
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
# 0   ETH per USDC
#
# [105 rows x 16 columns]

# %%
def import_results_file(filename, is_by_target=True):
    f = open(filename , "r")
    bm = f.read()
    if is_by_target:
        bm = bm.split('matchByTargetAmount')[1]
    else:
        bm = bm.split('matchByTargetAmount')[0]
    bm = bm.split('\n')
    bm = bm[1:]
    print(len(bm))
    bm = [x.replace('- order ','').replace(": ",",").replace('input = ','').replace(" output = ","") for x in bm]
    bm = [x.split(',') for x in bm]
    df = pd.DataFrame(bm, columns = ['result_id', 'input', 'output'])
    df.fillna('0', inplace=True)
    df = df[(df.input!='0')&(df.output!='0')].copy()
    df = df.astype(int)
    f.close()
    return(df)

# %%
df = import_results_file("256 orders with curr rate alternating - results.txt", is_by_target=False)
df
# Out:
# 106
#      result_id   input     output
# 0            1  150978  253827078
# 1          251  149494  250864116
# 2          248  148004  247901154
# 3           10  146509  244938192
# 4          242  145009  241975230
# ..         ...     ...        ...
# 99         199  139782  199506108
# 100         11    9698   13827156
# 101        196  138001  196543146
# 102          8    7637   10864194
# 103        193    2122    3581873
#
# [104 rows x 3 columns]

# %%
bysrc = FastSim.state()['trades'].query("id==173").query("subid!='A'")
bysrc.reset_index(inplace=True, drop=True)
bysrc['result_id'] = bysrc.routeix//2
resdf = pd.merge(bysrc, df, how='outer', on='result_id')

resdf['input_delta_perc'] = (resdf.amt1 - resdf.input) / resdf.input
resdf['output_delta_perc'] = (resdf.amt2 - resdf.output) / resdf.output
resdf
# Out:
#          uid   id subid        note   aggr   exec limitfail          amt1  \
# 0      173.0  173     0    route #2  False  False      None  2.538271e+08
# 1      173.1  173     1  route #502  False  False      None  2.508641e+08
# 2      173.2  173     2  route #496  False  False      None  2.479012e+08
# 3      173.3  173     3   route #20  False  False      None  2.449382e+08
# 4      173.4  173     4  route #484  False  False      None  2.419752e+08
# ..       ...  ...   ...         ...    ...    ...       ...           ...
# 99    173.99  173    99  route #398  False  False      None  1.995061e+08
# 100  173.100  173   100   route #22  False  False      None  1.382716e+07
# 101  173.101  173   101  route #392  False  False      None  1.965431e+08
# 102  173.102  173   102   route #16  False  False      None  1.086419e+07
# 103  173.103  173   103  route #386  False  False      None  3.667345e+06
#
#     tkn1           amt2  ...     pair routeix nroutes        price  \
# 0    ETH  150977.498776  ...  USDCETH       2       1  1548.218083
# 1    ETH  149493.441950  ...  USDCETH     502       1  1548.218083
# 2    ETH  148003.880519  ...  USDCETH     496       1  1548.218083
# 3    ETH  146508.782521  ...  USDCETH      20       1  1548.218083
# 4    ETH  145008.115739  ...  USDCETH     484       1  1548.218083
# ..   ...            ...  ...      ...     ...     ...          ...
# 99   ETH  139781.570435  ...  USDCETH     398       1  1548.218083
# 100  ETH    9697.309338  ...  USDCETH      22       1  1548.218083
# 101  ETH  138000.096341  ...  USDCETH     392       1  1548.218083
# 102  ETH    7636.342377  ...  USDCETH      16       1  1548.218083
# 103  ETH    2172.790155  ...  USDCETH     386       1  1548.218083
#
#            p_unit result_id   input     output  input_delta_perc  \
# 0    ETH per USDC         1  150978  253827078       1680.218972
# 1    ETH per USDC       251  149494  250864116       1677.088191
# 2    ETH per USDC       248  148004  247901154       1673.962528
# 3    ETH per USDC        10  146509  244938192       1670.830345
# 4    ETH per USDC       242  145009  241975230       1667.691116
# ..            ...       ...     ...        ...               ...
# 99   ETH per USDC       199  139782  199506108       1426.266086
# 100  ETH per USDC        11    9698   13827156       1424.773974
# 101  ETH per USDC       196  138001  196543146       1423.215375
# 102  ETH per USDC         8    7637   10864194       1421.573524
# 103  ETH per USDC       193    2122    3581873       1727.249158
#
#      output_delta_perc
# 0            -0.999405
# 1            -0.999404
# 2            -0.999403
# 3            -0.999402
# 4            -0.999401
# ..                 ...
# 99           -0.999299
# 100          -0.999299
# 101          -0.999298
# 102          -0.999297
# 103          -0.999393
#
# [104 rows x 21 columns]

# %%
max([abs(x) for x in resdf.output_delta_perc])
# Out:
# 0.9994051954583979

# %%
resdf.input.sum()
# Out:
# 10000000

# %%
resdf.amt2.sum()
# Out:
# 10000000.000003

# %%
resdf.output.sum()
# Out:
# 15482095361

# %%
resdf.amt1.sum()
# Out:
# 15482180832.712845

# %%
(resdf.amt1.sum() - resdf.output.sum()) / resdf.output.sum()
# Out:
# 5.520681203150008e-06

# %%
df = import_results_file("256 orders with curr rate alternating - results.txt", is_by_target=True)
df
# Out:
# 105
#      result_id      input  output
# 0            1  253827078  150978
# 1          251  250864116  149494
# 2          248  247901154  148004
# 3           10  244938192  146509
# 4          242  241975230  145009
# ..         ...        ...     ...
# 99         199  199506108  139782
# 100         11   13827156    9698
# 101        196  196543146  138001
# 102          8   10864194    7637
# 103        193    3581873    2122
#
# [104 rows x 3 columns]

# %%
bytrg = FastSim.state()['trades'].query("id==174").query("subid!='A'")
bytrg.reset_index(inplace=True, drop=True)
bytrg['result_id'] = bytrg.routeix//2
trgresdf = pd.merge(bytrg, df, how='outer', on='result_id')

trgresdf['input_delta_perc'] = (trgresdf.amt1 - trgresdf.input) / trgresdf.input
trgresdf['output_delta_perc'] = (trgresdf.amt2 - trgresdf.output) / trgresdf.output
trgresdf
# Out:
#          uid   id subid        note   aggr   exec limitfail          amt1  \
# 0      174.0  174     0    route #2  False  False      None  2.538271e+08
# 1      174.1  174     1  route #502  False  False      None  2.508641e+08
# 2      174.2  174     2  route #496  False  False      None  2.479012e+08
# 3      174.3  174     3   route #20  False  False      None  2.449382e+08
# 4      174.4  174     4  route #484  False  False      None  2.419752e+08
# ..       ...  ...   ...         ...    ...    ...       ...           ...
# 99    174.99  174    99  route #398  False  False      None  1.995061e+08
# 100  174.100  174   100   route #22  False  False      None  1.382716e+07
# 101  174.101  174   101  route #392  False  False      None  1.965431e+08
# 102  174.102  174   102   route #16  False  False      None  1.086419e+07
# 103  174.103  174   103  route #386  False  False      None  3.581873e+06
#
#     tkn1           amt2  ...     pair routeix nroutes        price  \
# 0    ETH  150977.498776  ...  USDCETH       2       1  1547.987616
# 1    ETH  149493.441950  ...  USDCETH     502       1  1547.987616
# 2    ETH  148003.880519  ...  USDCETH     496       1  1547.987616
# 3    ETH  146508.782521  ...  USDCETH      20       1  1547.987616
# 4    ETH  145008.115739  ...  USDCETH     484       1  1547.987616
# ..   ...            ...  ...      ...     ...     ...          ...
# 99   ETH  139781.570435  ...  USDCETH     398       1  1547.987616
# 100  ETH    9697.309338  ...  USDCETH      22       1  1547.987616
# 101  ETH  138000.096341  ...  USDCETH     392       1  1547.987616
# 102  ETH    7636.342377  ...  USDCETH      16       1  1547.987616
# 103  ETH    2121.999877  ...  USDCETH     386       1  1547.987616
#
#            p_unit result_id      input  output  input_delta_perc  \
# 0    ETH per USDC         1  253827078  150978      0.000000e+00
# 1    ETH per USDC       251  250864116  149494      0.000000e+00
# 2    ETH per USDC       248  247901154  148004      0.000000e+00
# 3    ETH per USDC        10  244938192  146509      0.000000e+00
# 4    ETH per USDC       242  241975230  145009      0.000000e+00
# ..            ...       ...        ...     ...               ...
# 99   ETH per USDC       199  199506108  139782      0.000000e+00
# 100  ETH per USDC        11   13827156    9698      0.000000e+00
# 101  ETH per USDC       196  196543146  138001      0.000000e+00
# 102  ETH per USDC         8   10864194    7637      0.000000e+00
# 103  ETH per USDC       193    3581873    2122      8.374920e-13
#
#      output_delta_perc
# 0        -3.319848e-06
# 1        -3.732926e-06
# 2        -8.072822e-07
# 3        -1.484407e-06
# 4        -6.097973e-06
# ..                 ...
# 99       -3.073107e-06
# 100      -7.121695e-05
# 101      -6.548206e-06
# 102      -8.611012e-05
# 103      -5.796418e-08
#
# [104 rows x 21 columns]

# %%
max([abs(x) for x in trgresdf.output_delta_perc])
# Out:
# 8.611012177557389e-05

# %%
trgresdf.input.sum()
# Out:
# 15482095361

# %%
trgresdf.amt1.sum()
# Out:
# 15482095361.000002

# %%
trgresdf.output.sum()
# Out:
# 10000000

# %%
trgresdf.amt2.sum()
# Out:
# 9999949.209725

# %%
(trgresdf.amt2.sum() - trgresdf.output.sum())/trgresdf.output.sum()
# Out:
# -5.079027500003576e-06
