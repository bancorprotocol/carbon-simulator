# %%
from carbon import CarbonSimulatorUI, P, __version__, __date__
print(f"Carbon v{__version__} ({__date__})")
print("{0.__name__} v{0.__VERSION__} ({0.__DATE__})".format(CarbonSimulatorUI))
# Out:
# Carbon v2.0-beta2 (8/Dec/2022)
# CarbonSimulatorUI v2.2 (8/Dec/2022)

# %% [markdown]
# # Carbon Simulation - Test 41 - Disabled Strategies and Orders

# %%
Sim = CarbonSimulatorUI(pair="ETH/USDC", raiseonerror=True)
Sim
# Out:
# CarbonSimulatorUI(<0 orders, 0 trades>, pair='ETH/USDC', mm='exact', xf=True)

# %% [markdown]
# ## Disabled Orders
# ### Base token

# %%
o = Sim.add_order("ETH", 100, 2000, 3000)["orders"]
assert(o.iloc[0]["y"] == 100)
assert(o.iloc[0]["y_int"] == 100)
assert(o.iloc[0]["p_start"] == 2000)
assert(o.iloc[0]["p_end"] == 3000)
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[0]["p_unit"] == "USDC per ETH")
o
# Out:
#    id     pair   tkn  y_int      y y_unit  disabled p_start   p_end  p_marg  \
# 0   0  ETHUSDC   ETH  100.0  100.0    ETH     False  2000.0  3000.0  2000.0
# 1   1  ETHUSDC  USDC    0.0    0.0   USDC      True    None    None    None
#
#          p_unit  lid
# 0  USDC per ETH    1
# 1  USDC per ETH    0

# %%
o = Sim.add_order("ETH", None, 2000, 3000)["orders"]
assert(o.iloc[0]["y"] == 0)
assert(o.iloc[0]["y_int"] == 0)
assert(o.iloc[0]["p_start"] == 2000)
assert(o.iloc[0]["p_end"] == 3000)
assert(o.iloc[0]["disabled"] == False)
o
# Out:
#    id     pair   tkn  y_int    y y_unit  disabled p_start   p_end  p_marg  \
# 2   2  ETHUSDC   ETH    0.0  0.0    ETH     False  2000.0  3000.0  2000.0
# 3   3  ETHUSDC  USDC    0.0  0.0   USDC      True    None    None    None
#
#          p_unit  lid
# 2  USDC per ETH    3
# 3  USDC per ETH    2

# %%
o = Sim.add_order("ETH", None, 3000, 2000)["orders"]
assert(o.iloc[0]["p_start"] == 2000)
assert(o.iloc[0]["p_end"] == 3000)
o
# Out:
# WARNING: swapped start and end of the range
#    id     pair   tkn  y_int    y y_unit  disabled p_start   p_end  p_marg  \
# 4   4  ETHUSDC   ETH    0.0  0.0    ETH     False  2000.0  3000.0  2000.0
# 5   5  ETHUSDC  USDC    0.0  0.0   USDC      True    None    None    None
#
#          p_unit  lid
# 4  USDC per ETH    5
# 5  USDC per ETH    4

# %%
o = Sim.add_order("ETH", 1, None, None)["orders"]
assert(o.iloc[0]["y"] == 1)
assert(o.iloc[0]["y_int"] == 1)
assert(o.iloc[0]["disabled"] == True)
assert(o.iloc[0]["p_start"] is None)
assert(o.iloc[0]["p_end"] is None)
assert(o.iloc[0]["p_marg"] is None)
o
# Out:
#    id     pair   tkn  y_int    y y_unit  disabled p_start p_end p_marg  \
# 6   6  ETHUSDC   ETH    1.0  1.0    ETH      True    None  None   None
# 7   7  ETHUSDC  USDC    0.0  0.0   USDC      True    None  None   None
#
#          p_unit  lid
# 6  USDC per ETH    7
# 7  USDC per ETH    6

# %%
o = Sim.add_order("ETH", None, None, None)["orders"]
assert(o.iloc[0]["y"] == 0)
assert(o.iloc[0]["y_int"] == 0)
o
# Out:
#    id     pair   tkn  y_int    y y_unit  disabled p_start p_end p_marg  \
# 8   8  ETHUSDC   ETH    0.0  0.0    ETH      True    None  None   None
# 9   9  ETHUSDC  USDC    0.0  0.0   USDC      True    None  None   None
#
#          p_unit  lid
# 8  USDC per ETH    9
# 9  USDC per ETH    8

# %% [markdown]
# ### Quote token

# %%
o = Sim.add_order("USDC", 1000, 1000, 750)["orders"]
assert(o.iloc[0]["y"] == 1000)
assert(o.iloc[0]["y_int"] == 1000)
assert(o.iloc[0]["p_start"] == 1000)
assert(o.iloc[0]["p_end"] == 750)
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[0]["p_unit"] == "USDC per ETH")
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start  p_end  p_marg  \
# 10  10  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1000.0  750.0  1000.0
# 11  11  ETHUSDC   ETH     0.0     0.0    ETH      True    None   None    None
#
#           p_unit  lid
# 10  USDC per ETH   11
# 11  USDC per ETH   10

# %%
o = Sim.add_order("USDC", None, 1000, 750)["orders"]
assert(o.iloc[0]["y"] == 0)
assert(o.iloc[0]["y_int"] == 0)
assert(o.iloc[0]["p_start"] == 1000)
assert(o.iloc[0]["p_end"] == 750)
assert(o.iloc[0]["disabled"] == False)
o
# Out:
#     id     pair   tkn  y_int    y y_unit  disabled p_start  p_end  p_marg  \
# 12  12  ETHUSDC  USDC    0.0  0.0   USDC     False  1000.0  750.0  1000.0
# 13  13  ETHUSDC   ETH    0.0  0.0    ETH      True    None   None    None
#
#           p_unit  lid
# 12  USDC per ETH   13
# 13  USDC per ETH   12

# %%
o = Sim.add_order("USDC", None, 750, 1000)["orders"]
assert(o.iloc[0]["p_start"] == 1000)
assert(o.iloc[0]["p_end"] == 750)
o
# Out:
# WARNING: swapped start and end of the range
#     id     pair   tkn  y_int    y y_unit  disabled p_start  p_end  p_marg  \
# 14  14  ETHUSDC  USDC    0.0  0.0   USDC     False  1000.0  750.0  1000.0
# 15  15  ETHUSDC   ETH    0.0  0.0    ETH      True    None   None    None
#
#           p_unit  lid
# 14  USDC per ETH   15
# 15  USDC per ETH   14

# %%
o = Sim.add_order("USDC", 1000, None, None)["orders"]
assert(o.iloc[0]["y"] == 1000)
assert(o.iloc[0]["y_int"] == 1000)
assert(o.iloc[0]["disabled"] == True)
assert(o.iloc[0]["p_start"] is None)
assert(o.iloc[0]["p_end"] is None)
assert(o.iloc[0]["p_marg"] is None)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start p_end p_marg  \
# 16  16  ETHUSDC  USDC  1000.0  1000.0   USDC      True    None  None   None
# 17  17  ETHUSDC   ETH     0.0     0.0    ETH      True    None  None   None
#
#           p_unit  lid
# 16  USDC per ETH   17
# 17  USDC per ETH   16

# %%
o = Sim.add_order("USDC", None, None, None)["orders"]
assert(o.iloc[0]["y"] == 0)
assert(o.iloc[0]["y_int"] == 0)
o
# Out:
#     id     pair   tkn  y_int    y y_unit  disabled p_start p_end p_marg  \
# 18  18  ETHUSDC  USDC    0.0  0.0   USDC      True    None  None   None
# 19  19  ETHUSDC   ETH    0.0  0.0    ETH      True    None  None   None
#
#           p_unit  lid
# 18  USDC per ETH   19
# 19  USDC per ETH   18

# %% [markdown]
# ### Fails

# %%
try:
    Sim.add_order("USDC", 10, None, 1000)
except ValueError as e:
    print(e)
    assert(str(e)=="('p_lo, p_hi must either be both None or both numbers', 1000, None)")
# Out:
# ('p_lo, p_hi must either be both None or both numbers', 1000, None)

# %%
try:
    Sim.add_order("ETH", 10, 2000, None)
except ValueError as e:
    print(e)
    assert(str(e)=="('p_lo, p_hi must either be both None or both numbers', None, 0.0005)")
# Out:
# ('p_lo, p_hi must either be both None or both numbers', None, 0.0005)

# %% [markdown]
# ## Disabled Strategies
# ### Base token

# %%
o = Sim.add_strategy("ETH", 10, 2000, 3000, 1000, 1000, 750)["orders"]
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[1]["disabled"] == False)
assert(o.iloc[0]["p_start"] == 2000)
assert(o.iloc[1]["p_start"] == 1000)
assert(o.iloc[0]["p_end"] == 3000)
assert(o.iloc[1]["p_end"] == 750)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled  p_start   p_end  \
# 24  24  ETHUSDC   ETH    10.0    10.0    ETH     False   2000.0  3000.0
# 25  25  ETHUSDC  USDC  1000.0  1000.0   USDC     False   1000.0   750.0
#
#     p_marg        p_unit  lid
# 24  2000.0  USDC per ETH   25
# 25  1000.0  USDC per ETH   24

# %%
o = Sim.add_strategy("ETH", 10, 3000, 2000, 1000, 750, 1000)["orders"]
assert(o.iloc[0]["p_start"] == 2000)
assert(o.iloc[1]["p_start"] == 1000)
assert(o.iloc[0]["p_end"] == 3000)
assert(o.iloc[1]["p_end"] == 750)
o
# Out:
# WARNING: swapped start and end of the range
# WARNING: swapped start and end of the range
#     id     pair   tkn   y_int       y y_unit  disabled  p_start   p_end  \
# 26  26  ETHUSDC   ETH    10.0    10.0    ETH     False   2000.0  3000.0
# 27  27  ETHUSDC  USDC  1000.0  1000.0   USDC     False   1000.0   750.0
#
#     p_marg        p_unit  lid
# 26  2000.0  USDC per ETH   27
# 27  1000.0  USDC per ETH   26

# %%
o = Sim.add_strategy("ETH", None, 2000, 3000, None, 1000, 750)["orders"]
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[1]["disabled"] == False)
o
# Out:
#     id     pair   tkn  y_int    y y_unit  disabled  p_start   p_end  p_marg  \
# 28  28  ETHUSDC   ETH    0.0  0.0    ETH     False   2000.0  3000.0  2000.0
# 29  29  ETHUSDC  USDC    0.0  0.0   USDC     False   1000.0   750.0  1000.0
#
#           p_unit  lid
# 28  USDC per ETH   29
# 29  USDC per ETH   28

# %%
o = Sim.add_strategy("ETH", 10, None, None, 1100, 1000, 750)["orders"]
assert(o.iloc[0]["y"] == 10)
assert(o.iloc[1]["y"] == 1100)
assert(o.iloc[0]["disabled"] == True)
assert(o.iloc[1]["disabled"] == False)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start  p_end  p_marg  \
# 30  30  ETHUSDC   ETH    10.0    10.0    ETH      True    None   None    None
# 31  31  ETHUSDC  USDC  1100.0  1100.0   USDC     False  1000.0  750.0  1000.0
#
#           p_unit  lid
# 30  USDC per ETH   31
# 31  USDC per ETH   30

# %%
o = Sim.add_strategy("ETH", 10, 2000, 3000, 1100, None, None)["orders"]
assert(o.iloc[0]["y"] == 10)
assert(o.iloc[1]["y"] == 1100)
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[1]["disabled"] == True)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  \
# 32  32  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
# 33  33  ETHUSDC  USDC  1100.0  1100.0   USDC      True    None    None
#
#     p_marg        p_unit  lid
# 32  2000.0  USDC per ETH   33
# 33    None  USDC per ETH   32

# %% [markdown]
# ### Quote token

# %%
o = Sim.add_strategy("USDC", 1000, 1000, 750, 10, 2000, 3000)["orders"]
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[1]["disabled"] == False)
assert(o.iloc[1]["p_start"] == 2000)
assert(o.iloc[0]["p_start"] == 1000)
assert(o.iloc[1]["p_end"] == 3000)
assert(o.iloc[0]["p_end"] == 750)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled  p_start   p_end  \
# 34  34  ETHUSDC  USDC  1000.0  1000.0   USDC     False   1000.0   750.0
# 35  35  ETHUSDC   ETH    10.0    10.0    ETH     False   2000.0  3000.0
#
#     p_marg        p_unit  lid
# 34  1000.0  USDC per ETH   35
# 35  2000.0  USDC per ETH   34

# %%
o = Sim.add_strategy("USDC", 1000, 750, 1000, 10, 3000, 2000)["orders"]
assert(o.iloc[0]["disabled"] == False)
assert(o.iloc[1]["disabled"] == False)
assert(o.iloc[1]["p_start"] == 2000)
assert(o.iloc[0]["p_start"] == 1000)
assert(o.iloc[1]["p_end"] == 3000)
assert(o.iloc[0]["p_end"] == 750)
o
# Out:
# WARNING: swapped start and end of the range
# WARNING: swapped start and end of the range
#     id     pair   tkn   y_int       y y_unit  disabled  p_start   p_end  \
# 36  36  ETHUSDC  USDC  1000.0  1000.0   USDC     False   1000.0   750.0
# 37  37  ETHUSDC   ETH    10.0    10.0    ETH     False   2000.0  3000.0
#
#     p_marg        p_unit  lid
# 36  1000.0  USDC per ETH   37
# 37  2000.0  USDC per ETH   36

# %%
o = Sim.add_strategy("USDC", 1100, None, None, 10, 2000, 3000)["orders"]
assert(o.iloc[0]["disabled"] == True)
assert(o.iloc[1]["disabled"] == False)
assert(o.iloc[0]["y"] == 1100)
assert(o.iloc[1]["y"] == 10)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  \
# 38  38  ETHUSDC  USDC  1100.0  1100.0   USDC      True    None    None
# 39  39  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0
#
#     p_marg        p_unit  lid
# 38    None  USDC per ETH   39
# 39  2000.0  USDC per ETH   38

# %%
o = Sim.add_strategy("USDC", 1100, None, None, 10, None, None)["orders"]
assert(o.iloc[0]["disabled"] == True)
assert(o.iloc[1]["disabled"] == True)
assert(o.iloc[0]["y"] == 1100)
assert(o.iloc[1]["y"] == 10)
o
# Out:
#     id     pair   tkn   y_int       y y_unit  disabled p_start p_end p_marg  \
# 40  40  ETHUSDC  USDC  1100.0  1100.0   USDC      True    None  None   None
# 41  41  ETHUSDC   ETH    10.0    10.0    ETH      True    None  None   None
#
#           p_unit  lid
# 40  USDC per ETH   41
# 41  USDC per ETH   40

# %% [markdown]
# ## Trading

# %%
Sim = CarbonSimulatorUI(pair="ETH/USDC", raiseonerror=True)
Sim.add_strategy("ETH", 10, 2000, 3000, 1000, 1000, 750)
Sim.add_strategy("ETH", 10, None, None, 1000, 1000, 750)
Sim.add_strategy("ETH", 10, 2000, 3000, 1000, None, None)
Sim.add_strategy("ETH", None, 2000, 3000, None, 1000, 750)
assert len(Sim.state()["orders"]) == 8
Sim.state()["orders"]
# Out:
#    id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  p_marg  \
# 0   0  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0  2000.0
# 1   1  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1000.0   750.0  1000.0
# 2   2  ETHUSDC   ETH    10.0    10.0    ETH      True    None    None    None
# 3   3  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1000.0   750.0  1000.0
# 4   4  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0  2000.0
# 5   5  ETHUSDC  USDC  1000.0  1000.0   USDC      True    None    None    None
# 6   6  ETHUSDC   ETH     0.0     0.0    ETH     False  2000.0  3000.0  2000.0
# 7   7  ETHUSDC  USDC     0.0     0.0   USDC     False  1000.0   750.0  1000.0
#
#          p_unit  lid
# 0  USDC per ETH    1
# 1  USDC per ETH    0
# 2  USDC per ETH    3
# 3  USDC per ETH    2
# 4  USDC per ETH    5
# 5  USDC per ETH    4
# 6  USDC per ETH    7
# 7  USDC per ETH    6

# %%
s = Sim.state()["orders"].query("disabled==False").query("y>0")
assert list(s["id"]) == [0,1,3,4]
s
# Out:
#    id     pair   tkn   y_int       y y_unit  disabled p_start   p_end  p_marg  \
# 0   0  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0  2000.0
# 1   1  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1000.0   750.0  1000.0
# 3   3  ETHUSDC  USDC  1000.0  1000.0   USDC     False  1000.0   750.0  1000.0
# 4   4  ETHUSDC   ETH    10.0    10.0    ETH     False  2000.0  3000.0  2000.0
#
#          p_unit  lid
# 0  USDC per ETH    1
# 1  USDC per ETH    0
# 3  USDC per ETH    2
# 4  USDC per ETH    5

# %%
t = Sim.amm_sells("ETH", 10)["trades"]
assert list(t["routeix"])[:-1] == [0,4]
t
# Out:
#    uid  id subid                            note   aggr  exec limitfail  amt1  \
# 0  0.0   0     0                        route #0  False  True      None   5.0
# 0  0.1   0     1                        route #4  False  True      None   5.0
# 0    0   0     A  AMM sells 10ETH buys 22020USDC   True  True      None  10.0
#
#   tkn1          amt2  tkn2     pair routeix  nroutes        price  \
# 0  ETH  11010.205144  USDC  ETHUSDC       0        1  2202.041029
# 0  ETH  11010.205144  USDC  ETHUSDC       4        1  2202.041029
# 0  ETH  22020.410289  USDC  ETHUSDC  [0, 4]        2  2202.041029
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH

# %%
s = Sim.state()["orders"].query("disabled==False").query("y>0")
s
# Out:
#    id     pair   tkn         y_int             y y_unit  disabled p_start  \
# 0   0  ETHUSDC   ETH     10.000000      5.000000    ETH     False  2000.0
# 1   1  ETHUSDC  USDC  12010.205144  12010.205144   USDC     False  1000.0
# 3   3  ETHUSDC  USDC   1000.000000   1000.000000   USDC     False  1000.0
# 4   4  ETHUSDC   ETH     10.000000      5.000000    ETH     False  2000.0
#
#     p_end       p_marg        p_unit  lid
# 0  3000.0  2424.492346  USDC per ETH    1
# 1   750.0       1000.0  USDC per ETH    0
# 3   750.0       1000.0  USDC per ETH    2
# 4  3000.0  2424.492346  USDC per ETH    5

# %%
t = Sim.amm_sells("USDC", 1000)["trades"]
assert list(t["routeix"])[:-1] == [1,3]
t
# Out:
#    uid  id subid                          note   aggr  exec limitfail  \
# 0  1.0   1     0                      route #1  False  True      None
# 0  1.1   1     1                      route #3  False  True      None
# 0    1   1     A  AMM sells 1000USDC buys 1ETH   True  True      None
#
#           amt1  tkn1      amt2 tkn2     pair routeix  nroutes       price  \
# 0   923.137261  USDC  0.932742  ETH  ETHUSDC       1        1  989.702346
# 0    76.862739  USDC  0.077662  ETH  ETHUSDC       3        1  989.702346
# 0  1000.000000  USDC  1.010405  ETH  ETHUSDC  [1, 3]        2  989.702346
#
#          p_unit
# 0  USDC per ETH
# 0  USDC per ETH
# 0  USDC per ETH
